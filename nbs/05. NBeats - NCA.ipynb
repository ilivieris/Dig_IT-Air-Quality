# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import random
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.ensemble      import RandomForestRegressor


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow 
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.plot_scatter       import *

# %% [markdown]
# # Parameters

# %%
import random, os

seed=42

random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = 'metadata/6-kanal-2.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        =   12
Horizon    =   6
#
epochs     =  200
batch_size =   16

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.08 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-01-29 00:00:06         25.4      17.0    1.2   1.7  214.0  298.0
# 1  2022-01-29 00:00:21         25.4      17.0    1.2   2.0  213.0  299.0
# 2  2022-01-29 00:00:41         25.3      17.0    1.2   1.4  214.0  299.0

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
df = pd.DataFrame( df['PM2.5'] )
df.head(3)
# Out:
#                         PM2.5
# Date
# 2022-01-29 00:00:00  1.227778
# 2022-01-29 00:05:00  1.833333
# 2022-01-29 00:10:00  1.626316

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ]
df_test  = df[ idx: ]

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train.plot(ax=ax, color='tab:blue' )
df_test.plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag-Horizon:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
        
    df_train = np.log( df_train )
    df_test  = np.log( df_test  )   
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scaler = MinMaxScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scaler = RobustScaler()
     
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
           
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    # Set scaler
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    
    dataX, dataY = [], []
    for idx in tqdm( range(0, df.shape[0] + 1  - Lag-Horizon - Horizon, overlap) ):
        
        data = df[ targetSeries ][idx:idx+Lag+Horizon].copy()
        
        Instances = []
        for i in range(1, Horizon+1):
            Instance  = data.diff(i)[-Lag:].to_list()
            Instance += [ df[ targetSeries ][idx+Lag+Horizon-1] ]
                        
            Instances += [ np.asarray(Instance) ]
            
        dataX.append( Instances )
        
       
    
    
        # Target Instance
        Instance = (df[ targetSeries ].to_numpy()[idx + Lag+Horizon : idx + Lag+Horizon + Horizon] - df[ targetSeries ][idx+Lag+Horizon-1] )

        # Append instance
        dataY.append( Instance )

        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Lag // 2)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 672/672 [00:00<00:00, 926.59it/s]
# 100%|██████████| 169/169 [00:00<00:00, 911.03it/s]
# Training instances:      672
# Testing instances:       169

# %%
trainX = np.swapaxes(trainX, 2, 1)
testX  = np.swapaxes(testX, 2, 1)

# %% [markdown]
# # Forecasting model: NBeats

# %% [markdown]
# ## Training process

# %%
from utils.NBeats_Keras import NBeatsNet

model = NBeatsNet(input_dim          = trainX.shape[2],
                  stack_types        = (NBeatsNet.GENERIC_BLOCK, NBeatsNet.GENERIC_BLOCK),
                  forecast_length    = Horizon,
                  backcast_length    = Lag,
                  hidden_layer_units = 64)

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 1.e-4), 
              metrics   = metrics)


# Checkpoint
#
checkpoint = ModelCheckpoint("models/NBeats_d-diff.hdf5", 
                              monitor        = 'val_RMSE', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_RMSE', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 20)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_RMSE', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX[:,:-1,], trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],                  
                  verbose         = 1, 
                  validation_data = (testX[:,:-1,:], testY))


# Terminate clock
#
stop = time.time()
print('[INFO] Time %.2f' % (stop - start))
# Out:
# Train on 672 samples, validate on 169 samples
# Epoch 1/200
# 672/672 [==============================] - 16s 25ms/sample - loss: 0.2791 - MAPE: 256576.4688 - RMSE: 0.5283 - val_loss: 0.2039 - val_MAPE: 304013.2812 - val_RMSE: 0.4516
# Epoch 2/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2703 - MAPE: 378269.5000 - RMSE: 0.5199 - val_loss: 0.2005 - val_MAPE: 369549.8125 - val_RMSE: 0.4478
# Epoch 3/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2670 - MAPE: 354223.6250 - RMSE: 0.5167 - val_loss: 0.1998 - val_MAPE: 471578.1250 - val_RMSE: 0.4470
# Epoch 4/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2655 - MAPE: 358867.0625 - RMSE: 0.5153 - val_loss: 0.1993 - val_MAPE: 530263.1250 - val_RMSE: 0.4465
# Epoch 5/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2642 - MAPE: 414176.1875 - RMSE: 0.5140 - val_loss: 0.1989 - val_MAPE: 612715.0000 - val_RMSE: 0.4460
# Epoch 6/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2631 - MAPE: 433842.1875 - RMSE: 0.5129 - val_loss: 0.1992 - val_MAPE: 601908.1875 - val_RMSE: 0.4463
# Epoch 7/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2627 - MAPE: 465489.6250 - RMSE: 0.5125 - val_loss: 0.1990 - val_MAPE: 611444.7500 - val_RMSE: 0.4461
# Epoch 8/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2621 - MAPE: 433125.0000 - RMSE: 0.5120 - val_loss: 0.1991 - val_MAPE: 637612.3125 - val_RMSE: 0.4462
# Epoch 9/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2616 - MAPE: 416670.4375 - RMSE: 0.5115 - val_loss: 0.1992 - val_MAPE: 516834.2812 - val_RMSE: 0.4463
# Epoch 10/200
# 672/672 [==============================] - 1s 1ms/sample - loss: 0.2608 - MAPE: 445224.6250 - RMSE: 0.5107 - val_loss: 0.1996 - val_MAPE: 628752.3125 - val_RMSE: 0.4467
# Epoch 11/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2598 - MAPE: 482442.3438 - RMSE: 0.5097 - val_loss: 0.1994 - val_MAPE: 637040.9375 - val_RMSE: 0.4466
# Epoch 12/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2596 - MAPE: 463138.4375 - RMSE: 0.5095 - val_loss: 0.1994 - val_MAPE: 568043.6250 - val_RMSE: 0.4465
# Epoch 13/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2596 - MAPE: 478668.5625 - RMSE: 0.5095 - val_loss: 0.1996 - val_MAPE: 582134.1250 - val_RMSE: 0.4467
# Epoch 14/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2592 - MAPE: 439383.3750 - RMSE: 0.5091 - val_loss: 0.1999 - val_MAPE: 566542.5625 - val_RMSE: 0.4471
# Epoch 15/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2587 - MAPE: 450773.9062 - RMSE: 0.5086 - val_loss: 0.1996 - val_MAPE: 606958.0000 - val_RMSE: 0.4468
# Epoch 16/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2583 - MAPE: 457051.2500 - RMSE: 0.5082 - val_loss: 0.1998 - val_MAPE: 583753.8750 - val_RMSE: 0.4470
# Epoch 17/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2581 - MAPE: 455208.4688 - RMSE: 0.5081 - val_loss: 0.1998 - val_MAPE: 567238.8125 - val_RMSE: 0.4470
# Epoch 18/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2580 - MAPE: 446087.4688 - RMSE: 0.5080 - val_loss: 0.1999 - val_MAPE: 568232.5000 - val_RMSE: 0.4471
# Epoch 19/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2579 - MAPE: 453030.5312 - RMSE: 0.5079 - val_loss: 0.2000 - val_MAPE: 578356.0625 - val_RMSE: 0.4472
# Epoch 20/200
# 672/672 [==============================] - 2s 3ms/sample - loss: 0.2578 - MAPE: 445988.8125 - RMSE: 0.5077 - val_loss: 0.1997 - val_MAPE: 566066.4375 - val_RMSE: 0.4469
# Epoch 21/200
# 672/672 [==============================] - 2s 3ms/sample - loss: 0.2575 - MAPE: 451748.6562 - RMSE: 0.5075 - val_loss: 0.1999 - val_MAPE: 562552.3125 - val_RMSE: 0.4471
# Epoch 22/200
# 672/672 [==============================] - 2s 3ms/sample - loss: 0.2576 - MAPE: 461203.6562 - RMSE: 0.5076 - val_loss: 0.2000 - val_MAPE: 575195.2500 - val_RMSE: 0.4472
# Epoch 23/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2575 - MAPE: 458611.1875 - RMSE: 0.5074 - val_loss: 0.1999 - val_MAPE: 577685.5625 - val_RMSE: 0.4471
# Epoch 24/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2575 - MAPE: 456026.9062 - RMSE: 0.5074 - val_loss: 0.2000 - val_MAPE: 560448.5625 - val_RMSE: 0.4472
# Epoch 25/200
# 672/672 [==============================] - 1s 2ms/sample - loss: 0.2574 - MAPE: 458643.3750 - RMSE: 0.5074 - val_loss: 0.1999 - val_MAPE: 578293.9375 - val_RMSE: 0.4471
# Epoch 00025: early stopping
# [INFO] Time 44.65

# %% [markdown]
# ## Evaluation

# %%
# Load the best model
#
model.load_weights('models/NBeats_d-diff.hdf5')

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %% [markdown]
# ### Get predictions

# %%
# Start clock
#
start = time.time()

pred = model.predict(testX[:,:-1,:]).squeeze(-1)

# Terminate clock
#
stop = time.time()

print('[INFO] Time %.2f' % (stop - start))
# Out:
# [INFO] Time 3.43

# %%
for i in range( Horizon ):
    testY[:, i] += testX[:,  -1,i]
    pred[:, i]  += testX[:,  -1,i]

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = scaler.inverse_transform( testY[:,  i] )
    Prices['Prediction'] = scaler.inverse_transform( pred[:, i]   )



    # Apply inverse transformation   
    #
    if (Transformation == True):
        Prices = np.exp( Prices )



    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]

    # Present results
    #
#     print('Horizon: ', i)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------
# Horizon:  1 MAE  0.13 SMAPE: 13.06 R2: 0.89
# Horizon:  2 MAE  0.20 SMAPE: 19.80 R2: 0.79
# Horizon:  3 MAE  0.25 SMAPE: 25.36 R2: 0.72
# Horizon:  4 MAE  0.30 SMAPE: 30.30 R2: 0.63
# Horizon:  5 MAE  0.34 SMAPE: 33.92 R2: 0.54
# Horizon:  6 MAE  0.35 SMAPE: 35.93 R2: 0.47

# %% [markdown]
# ### Residual examination

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = scaler.inverse_transform( testY[:,  i] )
    Prices['Prediction'] = scaler.inverse_transform( pred[:, i]   )



    # Apply inverse transformation   
    #
    if (Transformation == True):
        Prices = np.exp( Prices )
            
            

            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices['Prediction'] - Prices['Real']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------

# %% [markdown]
# ## Visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = scaler.inverse_transform( testY[:,  i] )
    Prices['Prediction'] = scaler.inverse_transform( pred[:, i]   )



    # Apply inverse transformation   
    #
    if (Transformation == True):
        Prices = np.exp( Prices )
            
            
    # Plot Real & Predicted values
    #
    Prices[:100].plot( figsize = (20, 3), marker = 'o' )
    #
    plt.title('Feature: {} - Horizon = {}'.format(targetSeries, i+1))
    plt.legend( frameon = False, fontsize = 14)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (30, 12) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    Real       = scaler.inverse_transform( testY[i] )
    Prediction = scaler.inverse_transform( pred[i]   )

    # Apply inverse transformation   
    #
    if (Transformation == True):
        Real       = np.exp( Real )
        Prediction = np.exp( Prediction )
        
    plt.subplot(subplots[plot_id])
    plt.grid()
    plot_scatter(range( Horizon ), Real, color='g')
    plot_scatter(range( Horizon ), Prediction, color='r')

    plt.legend(['Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
df_test = df[ idx: ]
df_test['NBeats_NCA'] = pred.flatten()

df_test.to_csv('Predictions/NBeats_NCA.csv')
