# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =   4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.31 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
df = pd.DataFrame( df['PM2.5'] )
df.head(3)
# Out:
#                         PM2.5
# Date
# 2022-02-19 00:00:00  2.457895
# 2022-02-19 00:05:00  2.494737
# 2022-02-19 00:10:00  2.494737

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()

# df['Hour'] = df.index.hour

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1, includeDate = False):
    
    if (targetSeries is None):
        print('[INFO] Target series is not defined')
        return (None, None, None)
    
    dataX, CurrentValue, dataY = [], [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):

        # Instances: Lag-d differences
        Instance  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy().tolist() 
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist(), 
                       np.cos(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            Instance = np.concatenate([Instance, myDate], axis = -1)

        # Current value
        CurrentValue.append( df[ targetSeries ].to_numpy()[i+Lag-1] )
        # Append instance
        dataX.append( Instance ) 
                
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )

        
    return ( np.array(dataX), np.array(dataY), np.array(CurrentValue) )

# %%
trainX, trainY, _                = create_dataset(df           = df_train, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,
                                                  overlap      = Horizon,)

testX,  testY, test_CurrentValue = create_dataset(df           = df_test, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,                                                
                                                  overlap      = 1)


# trainX = np.expand_dims(trainX, axis=-1)
# testX  = np.expand_dims(testX, axis=-1)
print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:01<00:00, 2494.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:01<00:00, 2554.79it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 11, 1), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]
# Out:
# 2022-05-04 13:37:02.333831: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *
# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )
# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')(Decoder)

# Output
#
# Outputs =  TimeDistributed(Dense(1, activation='linear'))( Decoder )
Outputs =  Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Seq2Seq_LSTM_diff.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
#
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 3s 11ms/step - loss: 0.2150 - MAE: 0.2790 - RMSE: 0.4636 - val_loss: 0.2798 - val_MAE: 0.3346 - val_RMSE: 0.5290 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.2091 - MAE: 0.2814 - RMSE: 0.4573 - val_loss: 0.2701 - val_MAE: 0.3280 - val_RMSE: 0.5197 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.2073 - MAE: 0.2817 - RMSE: 0.4553 - val_loss: 0.2626 - val_MAE: 0.3263 - val_RMSE: 0.5125 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.2044 - MAE: 0.2809 - RMSE: 0.4521 - val_loss: 0.2613 - val_MAE: 0.3313 - val_RMSE: 0.5112 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.2028 - MAE: 0.2800 - RMSE: 0.4504 - val_loss: 0.2617 - val_MAE: 0.3261 - val_RMSE: 0.5115 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.2022 - MAE: 0.2799 - RMSE: 0.4496 - val_loss: 0.2602 - val_MAE: 0.3226 - val_RMSE: 0.5101 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 2s 11ms/step - loss: 0.2015 - MAE: 0.2793 - RMSE: 0.4489 - val_loss: 0.2570 - val_MAE: 0.3236 - val_RMSE: 0.5069 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.2011 - MAE: 0.2792 - RMSE: 0.4484 - val_loss: 0.2527 - val_MAE: 0.3211 - val_RMSE: 0.5027 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.2008 - MAE: 0.2793 - RMSE: 0.4482 - val_loss: 0.2518 - val_MAE: 0.3230 - val_RMSE: 0.5018 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.2000 - MAE: 0.2798 - RMSE: 0.4472 - val_loss: 0.2559 - val_MAE: 0.3245 - val_RMSE: 0.5058 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.2003 - MAE: 0.2787 - RMSE: 0.4476 - val_loss: 0.2523 - val_MAE: 0.3271 - val_RMSE: 0.5023 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1994 - MAE: 0.2798 - RMSE: 0.4465 - val_loss: 0.2514 - val_MAE: 0.3187 - val_RMSE: 0.5014 - lr: 5.0000e-04
# Epoch 13/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1989 - MAE: 0.2791 - RMSE: 0.4459 - val_loss: 0.2573 - val_MAE: 0.3206 - val_RMSE: 0.5073 - lr: 5.0000e-04
# Epoch 14/200
# 134/134 [==============================] - 1s 8ms/step - loss: 0.1984 - MAE: 0.2797 - RMSE: 0.4454 - val_loss: 0.2514 - val_MAE: 0.3234 - val_RMSE: 0.5014 - lr: 5.0000e-04
# Epoch 15/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1990 - MAE: 0.2787 - RMSE: 0.4461 - val_loss: 0.2530 - val_MAE: 0.3280 - val_RMSE: 0.5030 - lr: 5.0000e-04
# Epoch 16/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1989 - MAE: 0.2794 - RMSE: 0.4460 - val_loss: 0.2513 - val_MAE: 0.3187 - val_RMSE: 0.5013 - lr: 5.0000e-04
# Epoch 17/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1991 - MAE: 0.2804 - RMSE: 0.4463 - val_loss: 0.2589 - val_MAE: 0.3273 - val_RMSE: 0.5088 - lr: 5.0000e-04
# Epoch 18/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1983 - MAE: 0.2782 - RMSE: 0.4453 - val_loss: 0.2527 - val_MAE: 0.3182 - val_RMSE: 0.5027 - lr: 5.0000e-04
# Epoch 19/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1977 - MAE: 0.2792 - RMSE: 0.4446 - val_loss: 0.2503 - val_MAE: 0.3185 - val_RMSE: 0.5003 - lr: 5.0000e-04
# Epoch 20/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1981 - MAE: 0.2790 - RMSE: 0.4451 - val_loss: 0.2517 - val_MAE: 0.3223 - val_RMSE: 0.5017 - lr: 5.0000e-04
# Epoch 21/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1976 - MAE: 0.2788 - RMSE: 0.4446 - val_loss: 0.2525 - val_MAE: 0.3216 - val_RMSE: 0.5025 - lr: 5.0000e-04
# Epoch 22/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1981 - MAE: 0.2795 - RMSE: 0.4451 - val_loss: 0.2523 - val_MAE: 0.3212 - val_RMSE: 0.5023 - lr: 5.0000e-04
# Epoch 23/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1975 - MAE: 0.2787 - RMSE: 0.4444 - val_loss: 0.2503 - val_MAE: 0.3217 - val_RMSE: 0.5003 - lr: 5.0000e-04
# Epoch 24/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1968 - MAE: 0.2784 - RMSE: 0.4436 - val_loss: 0.2547 - val_MAE: 0.3180 - val_RMSE: 0.5047 - lr: 5.0000e-04
# Epoch 25/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.1971 - MAE: 0.2791 - RMSE: 0.4440 - val_loss: 0.2513 - val_MAE: 0.3207 - val_RMSE: 0.5013 - lr: 2.5000e-04
# Epoch 26/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1960 - MAE: 0.2780 - RMSE: 0.4427 - val_loss: 0.2500 - val_MAE: 0.3208 - val_RMSE: 0.5000 - lr: 2.5000e-04
# Epoch 27/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1959 - MAE: 0.2783 - RMSE: 0.4426 - val_loss: 0.2507 - val_MAE: 0.3228 - val_RMSE: 0.5007 - lr: 2.5000e-04
# Epoch 28/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1959 - MAE: 0.2786 - RMSE: 0.4426 - val_loss: 0.2504 - val_MAE: 0.3221 - val_RMSE: 0.5004 - lr: 2.5000e-04
# Epoch 29/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1956 - MAE: 0.2779 - RMSE: 0.4423 - val_loss: 0.2509 - val_MAE: 0.3231 - val_RMSE: 0.5009 - lr: 2.5000e-04
# Epoch 30/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1954 - MAE: 0.2776 - RMSE: 0.4420 - val_loss: 0.2507 - val_MAE: 0.3248 - val_RMSE: 0.5007 - lr: 2.5000e-04
# Epoch 31/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.1955 - MAE: 0.2791 - RMSE: 0.4422 - val_loss: 0.2512 - val_MAE: 0.3224 - val_RMSE: 0.5012 - lr: 2.5000e-04
# Epoch 32/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1947 - MAE: 0.2770 - RMSE: 0.4412 - val_loss: 0.2484 - val_MAE: 0.3217 - val_RMSE: 0.4984 - lr: 1.2500e-04
# Epoch 33/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1944 - MAE: 0.2786 - RMSE: 0.4409 - val_loss: 0.2500 - val_MAE: 0.3220 - val_RMSE: 0.5000 - lr: 1.2500e-04
# Epoch 34/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1943 - MAE: 0.2766 - RMSE: 0.4408 - val_loss: 0.2499 - val_MAE: 0.3232 - val_RMSE: 0.4999 - lr: 1.2500e-04
# Epoch 35/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1943 - MAE: 0.2783 - RMSE: 0.4408 - val_loss: 0.2507 - val_MAE: 0.3184 - val_RMSE: 0.5007 - lr: 1.2500e-04
# Epoch 36/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1941 - MAE: 0.2765 - RMSE: 0.4406 - val_loss: 0.2484 - val_MAE: 0.3216 - val_RMSE: 0.4984 - lr: 1.2500e-04
# Epoch 37/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.1942 - MAE: 0.2783 - RMSE: 0.4407 - val_loss: 0.2490 - val_MAE: 0.3225 - val_RMSE: 0.4990 - lr: 1.2500e-04
# Epoch 38/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1935 - MAE: 0.2782 - RMSE: 0.4399 - val_loss: 0.2496 - val_MAE: 0.3193 - val_RMSE: 0.4996 - lr: 6.2500e-05
# Epoch 39/200
# 134/134 [==============================] - 1s 9ms/step - loss: 0.1935 - MAE: 0.2763 - RMSE: 0.4399 - val_loss: 0.2488 - val_MAE: 0.3209 - val_RMSE: 0.4988 - lr: 6.2500e-05
# Epoch 40/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1936 - MAE: 0.2782 - RMSE: 0.4400 - val_loss: 0.2490 - val_MAE: 0.3215 - val_RMSE: 0.4990 - lr: 6.2500e-05
# Epoch 41/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1934 - MAE: 0.2769 - RMSE: 0.4398 - val_loss: 0.2489 - val_MAE: 0.3216 - val_RMSE: 0.4989 - lr: 6.2500e-05
# Epoch 42/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.1934 - MAE: 0.2777 - RMSE: 0.4397 - val_loss: 0.2491 - val_MAE: 0.3192 - val_RMSE: 0.4991 - lr: 6.2500e-05
# Epoch 00042: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Seq2Seq_LSTM_diff.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = test_CurrentValue - testY[:, i]
    pred[:, i]  = test_CurrentValue - pred[:, i]

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue', marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  0.57 SMAPE: 18.45 R2: 0.74
# Horizon:  2 MAE  0.79 SMAPE: 25.65 R2: 0.52
# Horizon:  3 MAE  0.91 SMAPE: 30.09 R2: 0.40
# Horizon:  4 MAE  0.99 SMAPE: 33.41 R2: 0.33

# %%
# PM2.5 - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  0.57 SMAPE: 18.42 R2: 0.73
# Horizon:  2 MAE  0.79 SMAPE: 25.73 R2: 0.51
# Horizon:  3 MAE  0.91 SMAPE: 30.22 R2: 0.39
# Horizon:  4 MAE  0.99 SMAPE: 33.52 R2: 0.32

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Seq2Seq_LSTM_diff'] = pred.flatten()

Outputs.to_csv('Predictions/Seq2Seq_LSTM_diff.csv')
