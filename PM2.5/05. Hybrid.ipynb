# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.33 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()

# df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'PM10', 'PM2.5'] ] )
df = pd.DataFrame( df[ ['PM10', 'PM2.5'] ] )
# df = pd.DataFrame( df['PM2.5'] )

df.head(3)
# Out:
#                          PM10     PM2.5
# Date
# 2022-02-19 00:00:00  4.926316  2.457895
# 2022-02-19 00:05:00  5.689474  2.494737
# 2022-02-19 00:10:00  5.689474  2.494737

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()
#
# df['MA5'] = df[ targetSeries ].rolling(5).mean()
# df['MA9'] = df[ targetSeries ].rolling(9).mean()

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, includeLagData = False, includeDate = False, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Original data
        data       = df.to_numpy()[i+1:(i+Lag)]        
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist(), 
                       np.cos(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            # Concatenate data            
            data = np.concatenate([data, myDate], axis = -1)

        # data_diff: Lag-d differences
        if (includeLagData):
            data_diff  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy()
            #
            # Concatenate data
            data = np.concatenate([data, data_diff], axis = -1)
                
        
        # Concatenate data
        dataX.append( data )
        
        # Targets 
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df             = df_train, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = Horizon)
                               

testX,  testY  = create_dataset(df             = df_test, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0] )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:01<00:00, 2273.38it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:01<00:00, 2593.07it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 11, 4), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from tensorflow.keras.regularizers import l2

# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units       = 100, 
               activation  ='relu', 
               input_shape = (testX.shape[1], testX.shape[2]), 
               #
               kernel_regularizer    = l2(0.01), 
               recurrent_regularizer = l2(0.01), 
               bias_regularizer      = l2(0.01),
               # 
               return_sequences = True)( Inputs )
Encoder = LSTM(64, activation='relu')(Encoder)
#
# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(64, activation='relu', return_sequences=True)(Decoder)
Decoder = LSTM(units       = 100, 
               activation  ='relu', 
               #
               kernel_regularizer    = l2(0.01), 
               recurrent_regularizer = l2(0.01), 
               bias_regularizer      = l2(0.01),
               # 
               )(Decoder)

# Output
#
Outputs =  Dense( Horizon, activation='linear' )( Decoder )

# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)
# Out:
# 2022-05-11 11:24:39.838760: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Hybrid.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 40)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 20)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 6s 19ms/step - loss: 3.7722 - MAE: 0.5161 - RMSE: 0.6974 - val_loss: 2.5399 - val_MAE: 0.3525 - val_RMSE: 0.5204 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 2s 17ms/step - loss: 2.1255 - MAE: 0.3098 - RMSE: 0.4647 - val_loss: 1.9210 - val_MAE: 0.3396 - val_RMSE: 0.5136 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 2s 15ms/step - loss: 1.7262 - MAE: 0.3126 - RMSE: 0.4668 - val_loss: 1.6448 - val_MAE: 0.3415 - val_RMSE: 0.5167 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 2s 16ms/step - loss: 1.4822 - MAE: 0.3036 - RMSE: 0.4586 - val_loss: 1.4354 - val_MAE: 0.3517 - val_RMSE: 0.5149 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 2s 16ms/step - loss: 1.2937 - MAE: 0.3091 - RMSE: 0.4609 - val_loss: 1.2542 - val_MAE: 0.3416 - val_RMSE: 0.5092 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 3s 20ms/step - loss: 1.1289 - MAE: 0.3045 - RMSE: 0.4594 - val_loss: 1.1036 - val_MAE: 0.3460 - val_RMSE: 0.5112 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 3s 20ms/step - loss: 0.9815 - MAE: 0.2983 - RMSE: 0.4549 - val_loss: 0.9655 - val_MAE: 0.3330 - val_RMSE: 0.5070 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0
200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1938 - MAE: 0.2846 - RMSE: 0.4354 - val_loss: 0.2532 - val_MAE: 0.3276 - val_RMSE: 0.4991 - lr: 2.5000e-04
# Epoch 124/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1926 - MAE: 0.2838 - RMSE: 0.4341 - val_loss: 0.2527 - val_MAE: 0.3307 - val_RMSE: 0.4985 - lr: 2.5000e-04
# Epoch 125/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1938 - MAE: 0.2835 - RMSE: 0.4355 - val_loss: 0.2537 - val_MAE: 0.3232 - val_RMSE: 0.4995 - lr: 2.5000e-04
# Epoch 126/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1931 - MAE: 0.2849 - RMSE: 0.4347 - val_loss: 0.2579 - val_MAE: 0.3228 - val_RMSE: 0.5036 - lr: 2.5000e-04
# Epoch 127/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1909 - MAE: 0.2804 - RMSE: 0.4322 - val_loss: 0.2523 - val_MAE: 0.3308 - val_RMSE: 0.4982 - lr: 1.2500e-04
# Epoch 128/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1907 - MAE: 0.2791 - RMSE: 0.4320 - val_loss: 0.2517 - val_MAE: 0.3364 - val_RMSE: 0.4976 - lr: 1.2500e-04
# Epoch 129/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1905 - MAE: 0.2798 - RMSE: 0.4318 - val_loss: 0.2522 - val_MAE: 0.3319 - val_RMSE: 0.4982 - lr: 1.2500e-04
# Epoch 130/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1911 - MAE: 0.2800 - RMSE: 0.4325 - val_loss: 0.2507 - val_MAE: 0.3292 - val_RMSE: 0.4967 - lr: 1.2500e-04
# Epoch 131/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1909 - MAE: 0.2795 - RMSE: 0.4323 - val_loss: 0.2535 - val_MAE: 0.3334 - val_RMSE: 0.4994 - lr: 1.2500e-04
# Epoch 132/200
# 134/134 [==============================] - 2s 18ms/step - loss: 0.1916 - MAE: 0.2811 - RMSE: 0.4331 - val_loss: 0.2516 - val_MAE: 0.3333 - val_RMSE: 0.4976 - lr: 1.2500e-04
# Epoch 133/200
# 134/134 [==============================] - 3s 21ms/step - loss: 0.1902 - MAE: 0.2800 - RMSE: 0.4315 - val_loss: 0.2539 - val_MAE: 0.3231 - val_RMSE: 0.4999 - lr: 1.2500e-04
# Epoch 134/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1906 - MAE: 0.2805 - RMSE: 0.4320 - val_loss: 0.2537 - val_MAE: 0.3306 - val_RMSE: 0.4997 - lr: 1.2500e-04
# Epoch 135/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1897 - MAE: 0.2795 - RMSE: 0.4310 - val_loss: 0.2532 - val_MAE: 0.3302 - val_RMSE: 0.4993 - lr: 1.2500e-04
# Epoch 136/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1905 - MAE: 0.2807 - RMSE: 0.4320 - val_loss: 0.2510 - val_MAE: 0.3250 - val_RMSE: 0.4971 - lr: 1.2500e-04
# Epoch 137/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1905 - MAE: 0.2794 - RMSE: 0.4319 - val_loss: 0.2512 - val_MAE: 0.3261 - val_RMSE: 0.4973 - lr: 1.2500e-04
# Epoch 138/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1900 - MAE: 0.2807 - RMSE: 0.4314 - val_loss: 0.2509 - val_MAE: 0.3284 - val_RMSE: 0.4970 - lr: 1.2500e-04
# Epoch 139/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1903 - MAE: 0.2795 - RMSE: 0.4318 - val_loss: 0.2537 - val_MAE: 0.3255 - val_RMSE: 0.4998 - lr: 1.2500e-04
# Epoch 140/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1904 - MAE: 0.2806 - RMSE: 0.4319 - val_loss: 0.2531 - val_MAE: 0.3249 - val_RMSE: 0.4992 - lr: 1.2500e-04
# Epoch 141/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1903 - MAE: 0.2792 - RMSE: 0.4318 - val_loss: 0.2534 - val_MAE: 0.3322 - val_RMSE: 0.4995 - lr: 1.2500e-04
# Epoch 142/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1912 - MAE: 0.2818 - RMSE: 0.4328 - val_loss: 0.2535 - val_MAE: 0.3223 - val_RMSE: 0.4997 - lr: 1.2500e-04
# Epoch 143/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1901 - MAE: 0.2798 - RMSE: 0.4316 - val_loss: 0.2530 - val_MAE: 0.3280 - val_RMSE: 0.4991 - lr: 1.2500e-04
# Epoch 144/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1903 - MAE: 0.2802 - RMSE: 0.4318 - val_loss: 0.2511 - val_MAE: 0.3239 - val_RMSE: 0.4973 - lr: 1.2500e-04
# Epoch 145/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1912 - MAE: 0.2820 - RMSE: 0.4329 - val_loss: 0.2514 - val_MAE: 0.3242 - val_RMSE: 0.4975 - lr: 1.2500e-04
# Epoch 146/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1893 - MAE: 0.2790 - RMSE: 0.4307 - val_loss: 0.2567 - val_MAE: 0.3430 - val_RMSE: 0.5029 - lr: 1.2500e-04
# Epoch 00146: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Hybrid.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue', marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  0.59 SMAPE: 19.52 R2: 0.72
# Horizon:  2 MAE  0.80 SMAPE: 26.50 R2: 0.52
# Horizon:  3 MAE  0.92 SMAPE: 31.10 R2: 0.41
# Horizon:  4 MAE  1.00 SMAPE: 34.52 R2: 0.34

# %%
# PM2.5 + d-Lag - Log+StandardScaler
# --------------------------------------------------
# Horizon:  1 MAE  0.56 SMAPE: 18.49 R2: 0.74
# Horizon:  2 MAE  0.78 SMAPE: 25.80 R2: 0.53
# Horizon:  3 MAE  0.91 SMAPE: 30.87 R2: 0.42
# Horizon:  4 MAE  0.99 SMAPE: 34.61 R2: 0.35


# All-data + d-Lag - Log+StandardScaler
# --------------------------------------------------
# Horizon:  1 MAE  0.60 SMAPE: 20.31 R2: 0.72
# Horizon:  2 MAE  0.83 SMAPE: 28.05 R2: 0.52
# Horizon:  3 MAE  0.94 SMAPE: 32.48 R2: 0.41
# Horizon:  4 MAE  1.03 SMAPE: 36.38 R2: 0.34


# PM2.5 + MA6/12 + d-Lag - Log+StandardScaler
# --------------------------------------------------
# Horizon:  1 MAE  0.59 SMAPE: 19.93 R2: 0.73
# Horizon:  2 MAE  0.81 SMAPE: 27.82 R2: 0.52
# Horizon:  3 MAE  0.92 SMAPE: 31.90 R2: 0.41
# Horizon:  4 MAE  1.00 SMAPE: 34.95 R2: 0.34


# PM2.5 + PM10 + Time + d-Lag - Log+StandardScaler
# --------------------------------------------------
# Horizon:  1 MAE  0.57 SMAPE: 18.93 R2: 0.74
# Horizon:  2 MAE  0.79 SMAPE: 26.01 R2: 0.52
# Horizon:  3 MAE  0.90 SMAPE: 30.14 R2: 0.41
# Horizon:  4 MAE  0.98 SMAPE: 33.43 R2: 0.33

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )  
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Hybrid']       = pred.flatten()

Outputs.to_csv('Predictions/Hybrid.csv')
