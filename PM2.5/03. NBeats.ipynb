# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow 
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.plot_scatter       import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        =   12
Horizon    =   4
#
epochs     =  200
batch_size =   16

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.30 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'PM10', 'PM2.5'] ] )
# df = pd.DataFrame( df[ ['PM2.5'] ] )
df.head(3)
# Out:
#                      Temperature  Humidity      PM10     PM2.5
# Date
# 2022-02-19 00:00:00    -2.415789      86.0  4.926316  2.457895
# 2022-02-19 00:05:00    -2.421053      86.0  5.689474  2.494737
# 2022-02-19 00:10:00    -2.436842      86.0  5.689474  2.494737

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train[targetSeries].plot(ax=ax, color='tab:blue' )
df_test[targetSeries].plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(abs( -df.min().min() ), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = MinMaxScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = MinMaxScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = RobustScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = RobustScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )             
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Standard
# Feature:  Temperature
# Feature:  Humidity
# Feature:  PM10

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon,)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1,)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:00<00:00, 114282.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:00<00:00, 115519.60it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 12, 4), (4276, 4))

# %% [markdown]
# # Forecasting model: NBeats

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from utils.NBeats_Keras import NBeatsNet

model = NBeatsNet(stack_types         = (NBeatsNet.SEASONALITY_BLOCK, NBeatsNet.TREND_BLOCK),
                  forecast_length     = Horizon,
                  input_dim           = trainX.shape[2],
                  backcast_length     = trainX.shape[1],
                  hidden_layer_units  = 256, 
                  activation_function = 'relu')
# Out:
# 2022-05-05 10:28:52.315251: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training parameters

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]

model.compile(loss = 'mse', optimizer = Adam(learning_rate = 5.e-4), metrics = metrics)
#

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/NBeats.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY,                   
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  shuffle         = True,
                  verbose         = 1, 
                  validation_data = (testX, testY))


# Terminate clock
#
stop = time.time()
print('[INFO] Time %.2f' % (stop - start))
# Out:
# Epoch 1/200
# 268/268 [==============================] - 11s 21ms/step - loss: 0.2255 - MAE: 0.3077 - RMSE: 0.4748 - val_loss: 0.2439 - val_MAE: 0.3157 - val_RMSE: 0.4939 - lr: 5.0000e-04
# Epoch 2/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.2069 - MAE: 0.2926 - RMSE: 0.4549 - val_loss: 0.2449 - val_MAE: 0.3152 - val_RMSE: 0.4949 - lr: 5.0000e-04
# Epoch 3/200
# 268/268 [==============================] - 4s 14ms/step - loss: 0.2072 - MAE: 0.2917 - RMSE: 0.4552 - val_loss: 0.2444 - val_MAE: 0.3194 - val_RMSE: 0.4944 - lr: 5.0000e-04
# Epoch 4/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.2027 - MAE: 0.2851 - RMSE: 0.4503 - val_loss: 0.2444 - val_MAE: 0.3214 - val_RMSE: 0.4944 - lr: 5.0000e-04
# Epoch 5/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.2031 - MAE: 0.2876 - RMSE: 0.4507 - val_loss: 0.2485 - val_MAE: 0.3245 - val_RMSE: 0.4985 - lr: 5.0000e-04
# Epoch 6/200
# 268/268 [==============================] - 4s 15ms/step - loss: 0.2016 - MAE: 0.2856 - RMSE: 0.4490 - val_loss: 0.2426 - val_MAE: 0.3162 - val_RMSE: 0.4926 - lr: 5.0000e-04
# Epoch 7/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1999 - MAE: 0.2843 - RMSE: 0.4472 - val_loss: 0.2429 - val_MAE: 0.3029 - val_RMSE: 0.4929 - lr: 5.0000e-04
# Epoch 8/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1985 - MAE: 0.2808 - RMSE: 0.4455 - val_loss: 0.2440 - val_MAE: 0.3279 - val_RMSE: 0.4940 - lr: 5.0000e-04
# Epoch 9/200
# 268/268 [==============================] - 3s 12ms/step - loss: 0.2025 - MAE: 0.2850 - RMSE: 0.4500 - val_loss: 0.2503 - val_MAE: 0.2964 - val_RMSE: 0.5003 - lr: 5.0000e-04
# Epoch 10/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.2001 - MAE: 0.2836 - RMSE: 0.4474 - val_loss: 0.2439 - val_MAE: 0.3111 - val_RMSE: 0.4939 - lr: 5.0000e-04
# Epoch 11/200
# 268/268 [==============================] - 4s 14ms/step - loss: 0.1978 - MAE: 0.2799 - RMSE: 0.4448 - val_loss: 0.2390 - val_MAE: 0.3100 - val_RMSE: 0.4889 - lr: 5.0000e-04
# Epoch 12/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1959 - MAE: 0.2805 - RMSE: 0.4426 - val_loss: 0.2427 - val_MAE: 0.2934 - val_RMSE: 0.4926 - lr: 5.0000e-04
# Epoch 13/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1967 - MAE: 0.2803 - RMSE: 0.4435 - val_loss: 0.2383 - val_MAE: 0.3101 - val_RMSE: 0.4882 - lr: 5.0000e-04
# Epoch 14/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1969 - MAE: 0.2803 - RMSE: 0.4437 - val_loss: 0.2460 - val_MAE: 0.3029 - val_RMSE: 0.4959 - lr: 5.0000e-04
# Epoch 15/200
# 268/268 [==============================] - 4s 15ms/step - loss: 0.1971 - MAE: 0.2793 - RMSE: 0.4440 - val_loss: 0.2393 - val_MAE: 0.3146 - val_RMSE: 0.4892 - lr: 5.0000e-04
# Epoch 16/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1947 - MAE: 0.2782 - RMSE: 0.4412 - val_loss: 0.2392 - val_MAE: 0.3022 - val_RMSE: 0.4890 - lr: 5.0000e-04
# Epoch 17/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1958 - MAE: 0.2799 - RMSE: 0.4425 - val_loss: 0.2366 - val_MAE: 0.3083 - val_RMSE: 0.4865 - lr: 5.0000e-04
# Epoch 18/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1949 - MAE: 0.2781 - RMSE: 0.4415 - val_loss: 0.2380 - val_MAE: 0.2988 - val_RMSE: 0.4878 - lr: 5.0000e-04
# Epoch 19/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1953 - MAE: 0.2780 - RMSE: 0.4419 - val_loss: 0.2373 - val_MAE: 0.2943 - val_RMSE: 0.4872 - lr: 5.0000e-04
# Epoch 20/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1940 - MAE: 0.2763 - RMSE: 0.4405 - val_loss: 0.2370 - val_MAE: 0.3057 - val_RMSE: 0.4868 - lr: 5.0000e-04
# Epoch 21/200
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1938 - MAE: 0.2779 - RMSE: 0.4402 - val_loss: 0.2403 - val_MAE: 0.3046 - val_RMSE: 0.4902 - lr: 5.0000e-04
# Epoch 22/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1935 - MAE: 0.2761 - RMSE: 0.4399 - val_loss: 0.2435 - val_MAE: 0.2944 - val_RMSE: 0.4935 - lr: 5.0000e-04
# Epoch 23/200
# 268/268 [==============================] - 4s 13ms/step - loss: 0.1901 - MAE: 0.2723 - RMSE: 0.4360 - val_loss: 0.2385 - val_MAE: 0.3050 - val_RMSE: 0.4884 - lr: 2.5000e-04
# Epoch 24/200
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1890 - MAE: 0.2734 - RMSE: 0.4347 - val_loss: 0.2369 - val_MAE: 0.2986 - val_RMSE: 0.4867 - lr: 2.5000e-04
# Epoch 25/200
# 268/268 [==============================] - 4s 14ms/step - loss: 0.1889 - MAE: 0.2716 - RMSE: 0.4346 - val_loss: 0.2385 - val_MAE: 0.3073 - val_RMSE: 0.4884 - lr: 2.5000e-04
# Epoch 26/200
# 268/268 [==============================] - 4s 14ms/step - loss: 0.1892 - MAE: 0.2735 - RMSE: 0.4350 - val_loss: 0.2417 - val_MAE: 0.2978 - val_RMSE: 0.4916 - lr: 2.5000e-04
# Epoch 27/200
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1891 - MAE: 0.2715 - RMSE: 0.4348 - val_loss: 0.2401 - val_MAE: 0.3048 - val_RMSE: 0.4900 - lr: 2.5000e-04
# Epoch 00027: early stopping
# [INFO] Time 103.53

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Valdiation'], frameon = False);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized model

# %%
# Load the best model
#
model.load_weights('models/NBeats.hdf5')

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
# Get predictions
#
pred = model.predict( testX ).squeeze(-1)

# %%
testY.shape, pred.shape
# Out:
# ((4277, 4), (4277, 4))

# %% [markdown]
# ### Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]


    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]

    # Present results
    #
#     print('Horizon: ', i+1)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' % (i+1, MAE, SMAPE, R2) )
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------
# Horizon:  1 MAE  0.62 SMAPE: 22.29 R2: 0.72
# Horizon:  2 MAE  0.82 SMAPE: 28.44 R2: 0.52
# Horizon:  3 MAE  0.96 SMAPE: 33.67 R2: 0.40
# Horizon:  4 MAE  1.05 SMAPE: 37.45 R2: 0.33

# %%
# PM2.5 - Log+StandardScaler
# ------------------------------------------------
# [INFO] Feature:  PM2.5
# ------------------------------------------------
# Horizon:  1 MAE  0.58 SMAPE: 19.86 R2: 0.73
# Horizon:  2 MAE  0.82 SMAPE: 27.78 R2: 0.52
# Horizon:  3 MAE  0.98 SMAPE: 34.98 R2: 0.41
# Horizon:  4 MAE  1.06 SMAPE: 37.71 R2: 0.33

# %% [markdown]
# ### Residual examination

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
            
            

            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------

# %% [markdown]
# ## Visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = scaler.inverse_transform( testY[:,  i] )
    Prices['Prediction'] = scaler.inverse_transform( pred[:, i]   )


            
            
    # Plot Real & Predicted values
    #
    Prices[:100].plot( figsize = (20, 3), marker = 'o' )
    #
    plt.title('Feature: {} - Horizon = {}'.format(targetSeries, i+1))
    plt.legend( frameon = False, fontsize = 14)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
# Out:
# [INFO] Feature:  PM2.5
# ------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.grid()
#     plot_scatter(range(0, Lag),             testX[i,:Lag], color='b')
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame([])
#
#
Outputs[targetSeries] = testY.flatten()
Outputs['NBeats']     = pred.flatten()
#
Outputs.to_csv('Predictions/NBeats.csv')
