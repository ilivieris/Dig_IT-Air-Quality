# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    2
#
epochs     =  500
batch_size =  128

Transformation = True

# %% [markdown]
# # Importing data

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Data concern the concentration from a mine in Norway
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

 

# # Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'



# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.28 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %%
# # Parameters
# #
# filename   = '../Data/D-6-It.csv'

# Transformation  = True
# Scaling         = 'Standard'




# # Start timer
# #
# start = time.time()

# # Load data
# #
# df = pd.read_csv(filename, 
#                  sep = ',')


# # Rename columns
# #
# df = df.rename(columns = {'created_at' : 'Date',
#                           'field1' : 'Temperature',
#                           'field2' : 'Humidity',
#                           'field3' : 'PM2.5',
#                           'field4' : 'PM10',
#                           'field5' : 'NO2',
#                           'field6' : 'CO',
#                           'field7' : 'NH4',})



# # End timer
# #
# print('[INFO] Time: %.2f' % (time.time() - start))

# df.head( 3 )

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)



df = df.resample('10min').mean() 
#
df = pd.DataFrame( df[ ['NO2', 'CO'] ] )
# df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'NO2', 'CO'] ] )


df.head(3)
# Out:
#                             NO2          CO
# Date
# 2022-02-19 00:00:00  168.631579  240.710526
# 2022-02-19 00:10:00  135.394737  227.473684
# 2022-02-19 00:20:00  141.447368  229.526316

# %%
# Set target series/Series which will be forecasted
# 
targetSeries = df.columns[-1]

# Set all other utilized features
Features = df.columns[:-1]

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ] 
df_test  = df[ idx: ]

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  8558
# Testing:   2140

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Testing'], fontsize = 12, frameon = False);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(abs( -df.min().min() ) + 1.0, 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)

    # # Transformation parameter
    # #
    # d = {'parameter': VALUE}

    # import json
    # with open('checkpoints/Transformation.json', 'w') as fp:
    #     json.dump(d, fp)
    # print('[INFO] Parameters saved')

else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
import pickle

if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scaler = MinMaxScaler()
    
    df_train[ Features ] = scaler.fit_transform( df_train[ Features ].to_numpy().reshape(-1,1) )
    df_test[ Features ]  = scaler.transform( df_test[ Features ].to_numpy().reshape(-1,1) )

    # # Save Scaler
    # #
    # filename = 'checkpoints/Feature_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Feature scaler saved in ', filename)


    # Scaling of Target Series
    #
    scaler = MinMaxScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
    # # Save Scaler
    # #
    # filename = 'checkpoints/Target_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Target scaler saved in ', filename)

    
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scaler = RobustScaler()
    
    df_train[ Features ] = scaler.fit_transform( df_train[ Features ].to_numpy().reshape(-1,1) )
    df_test[ Features ]  = scaler.transform( df_test[ Features ].to_numpy().reshape(-1,1) )

    # # Save Scaler
    # #
    # filename = 'checkpoints/Feature_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Feature scaler saved in ', filename)


    # Scaling of Target Series
    #
    scaler = RobustScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
    # # Save Scaler
    # #
    # filename = 'checkpoints/Target_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Target scaler saved in ', filename)
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    # Set scaler
    #
    scaler = StandardScaler()
    
    df_train[ Features ] = scaler.fit_transform( df_train[ Features ].to_numpy().reshape(-1,1) )
    df_test[ Features ]  = scaler.transform( df_test[ Features ].to_numpy().reshape(-1,1) )

    # # Save Scaler
    # #
    # filename = 'checkpoints/Feature_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Feature scaler saved in ', filename)


    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
    # # Save Scaler
    # #
    # filename = 'checkpoints/Target_scaler.pkl'
    # pickle.dump(scaler, open(filename, 'wb'))
    # print('[INFO] Target scaler saved in ', filename)       
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Check for NaN values
        if (df[i:i + Lag + Horizon].dropna().shape[0] != df[i:i + Lag + Horizon].shape[0]): continue
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 8545/8545 [00:06<00:00, 1406.93it/s]
# 100%|██████████| 1070/1070 [00:00<00:00, 1413.77it/s]
# Training instances:     8545
# Testing instances:      1070

# %% [markdown]
# # Forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]
# Out:
# 2022-10-12 13:21:32.573510: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *
# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )
# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')(Decoder)

# Output
#
# Outputs =  TimeDistributed(Dense(1, activation='linear'))( Decoder )
Outputs =  Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("checkpoints/Seq2Seq_LSTM.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = [checkpoint, earlystopping, lrs_scheduler],
                  verbose          = 1, 
                  shuffle          = True,
                  validation_split = 0.2)


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/500
# 54/54 [==============================] - 2s 17ms/step - loss: 0.6380 - MAE: 0.6431 - RMSE: 0.7988 - val_loss: 0.5349 - val_MAE: 0.6067 - val_RMSE: 0.7313 - lr: 5.0000e-04
# Epoch 2/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.2919 - MAE: 0.4087 - RMSE: 0.5402 - val_loss: 0.3464 - val_MAE: 0.4639 - val_RMSE: 0.5885 - lr: 5.0000e-04
# Epoch 3/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.2188 - MAE: 0.3400 - RMSE: 0.4678 - val_loss: 0.2862 - val_MAE: 0.3997 - val_RMSE: 0.5349 - lr: 5.0000e-04
# Epoch 4/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1935 - MAE: 0.3141 - RMSE: 0.4398 - val_loss: 0.2549 - val_MAE: 0.3477 - val_RMSE: 0.5048 - lr: 5.0000e-04
# Epoch 5/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1842 - MAE: 0.2999 - RMSE: 0.4292 - val_loss: 0.2560 - val_MAE: 0.3809 - val_RMSE: 0.5060 - lr: 5.0000e-04
# Epoch 6/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1769 - MAE: 0.2927 - RMSE: 0.4205 - val_loss: 0.2403 - val_MAE: 0.3368 - val_RMSE: 0.4902 - lr: 5.0000e-04
# Epoch 7/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1752 - MAE: 0.2896 - RMSE: 0.4186 - val_loss: 0.2420 - val_MAE: 0.3612 - val_RMSE: 0.4920 - lr: 5.0000e-04
# Epoch 8/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1741 - MAE: 0.2909 - RMSE: 0.4172 - val_loss: 0.2476 - val_MAE: 0.3594 - val_RMSE: 0.4976 - lr: 5.0000e-04
# Epoch 9/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1726 - MAE: 0.2880 - RMSE: 0.4155 - val_loss: 0.2353 - val_MAE: 0.3274 - val_RMSE: 0.4851 - lr: 5.0000e-04
# Epoch 10/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1729 - MAE: 0.2880 - RMSE: 0.4158 - val_loss: 0.2302 - val_MAE: 0.3347 - val_RMSE: 0.4798 - lr: 5.0000e-04
# Epoch 11/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1696 - MAE: 0.2838 - RMSE: 0.4119 - val_loss: 0.2327 - val_MAE: 0.3445 - val_RMSE: 0.4824 - lr: 5.0000e-04
# Epoch 12/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1695 - MAE: 0.2832 - RMSE: 0.4117 - val_loss: 0.2291 - val_MAE: 0.3356 - val_RMSE: 0.4786 - lr: 5.0000e-04
# Epoch 13/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1690 - MAE: 0.2833 - RMSE: 0.4111 - val_loss: 0.2353 - val_MAE: 0.3482 - val_RMSE: 0.4851 - lr: 5.0000e-04
# Epoch 14/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1697 - MAE: 0.2843 - RMSE: 0.4119 - val_loss: 0.2323 - val_MAE: 0.3456 - val_RMSE: 0.4820 - lr: 5.0000e-04
# Epoch 15/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1671 - MAE: 0.2813 - RMSE: 0.4088 - val_loss: 0.2290 - val_MAE: 0.3305 - val_RMSE: 0.4785 - lr: 5.0000e-04
# Epoch 16/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1693 - MAE: 0.2835 - RMSE: 0.4115 - val_loss: 0.2279 - val_MAE: 0.3402 - val_RMSE: 0.4774 - lr: 5.0000e-04
# Epoch 17/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1661 - MAE: 0.2799 - RMSE: 0.4076 - val_loss: 0.2325 - val_MAE: 0.3379 - val_RMSE: 0.4822 - lr: 5.0000e-04
# Epoch 18/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1686 - MAE: 0.2836 - RMSE: 0.4106 - val_loss: 0.2321 - val_MAE: 0.3468 - val_RMSE: 0.4817 - lr: 5.0000e-04
# Epoch 19/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1660 - MAE: 0.2797 - RMSE: 0.4075 - val_loss: 0.2346 - val_MAE: 0.3531 - val_RMSE: 0.4843 - lr: 5.0000e-04
# Epoch 20/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1656 - MAE: 0.2802 - RMSE: 0.4070 - val_loss: 0.2285 - val_MAE: 0.3396 - val_RMSE: 0.4780 - lr: 5.0000e-04
# Epoch 21/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1652 - MAE: 0.2784 - RMSE: 0.4065 - val_loss: 0.2242 - val_MAE: 0.3297 - val_RMSE: 0.4735 - lr: 5.0000e-04
# Epoch 22/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1645 - MAE: 0.2784 - RMSE: 0.4056 - val_loss: 0.2256 - val_MAE: 0.3278 - val_RMSE: 0.4750 - lr: 5.0000e-04
# Epoch 23/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1669 - MAE: 0.2816 - RMSE: 0.4086 - val_loss: 0.2265 - val_MAE: 0.3434 - val_RMSE: 0.4759 - lr: 5.0000e-04
# Epoch 24/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1635 - MAE: 0.2777 - RMSE: 0.4044 - val_loss: 0.2300 - val_MAE: 0.3283 - val_RMSE: 0.4796 - lr: 5.0000e-04
# Epoch 25/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1665 - MAE: 0.2810 - RMSE: 0.4080 - val_loss: 0.2256 - val_MAE: 0.3415 - val_RMSE: 0.4750 - lr: 5.0000e-04
# Epoch 26/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1659 - MAE: 0.2811 - RMSE: 0.4073 - val_loss: 0.2276 - val_MAE: 0.3289 - val_RMSE: 0.4771 - lr: 5.0000e-04
# Epoch 27/500
# 54/54 [==============================] - 1s 17ms/step - loss: 0.1636 - MAE: 0.2774 - RMSE: 0.4044 - val_loss: 0.2234 - val_MAE: 0.3335 - val_RMSE: 0.4726 - lr: 2.5000e-04
# Epoch 28/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1622 - MAE: 0.2761 - RMSE: 0.4028 - val_loss: 0.2236 - val_MAE: 0.3263 - val_RMSE: 0.4729 - lr: 2.5000e-04
# Epoch 29/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1623 - MAE: 0.2754 - RMSE: 0.4029 - val_loss: 0.2232 - val_MAE: 0.3297 - val_RMSE: 0.4724 - lr: 2.5000e-04
# Epoch 30/500
# 54/54 [==============================] - 1s 15ms/step - loss: 0.1616 - MAE: 0.2752 - RMSE: 0.4020 - val_loss: 0.2270 - val_MAE: 0.3385 - val_RMSE: 0.4764 - lr: 2.5000e-04
# Epoch 31/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1623 - MAE: 0.2757 - RMSE: 0.4028 - val_loss: 0.2224 - val_MAE: 0.3284 - val_RMSE: 0.4716 - lr: 2.5000e-04
# Epoch 32/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1623 - MAE: 0.2767 - RMSE: 0.4029 - val_loss: 0.2233 - val_MAE: 0.3266 - val_RMSE: 0.4726 - lr: 2.5000e-04
# Epoch 33/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1617 - MAE: 0.2748 - RMSE: 0.4021 - val_loss: 0.2282 - val_MAE: 0.3459 - val_RMSE: 0.4777 - lr: 2.5000e-04
# Epoch 34/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1616 - MAE: 0.2748 - RMSE: 0.4020 - val_loss: 0.2230 - val_MAE: 0.3362 - val_RMSE: 0.4722 - lr: 2.5000e-04
# Epoch 35/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1637 - MAE: 0.2784 - RMSE: 0.4046 - val_loss: 0.2236 - val_MAE: 0.3327 - val_RMSE: 0.4728 - lr: 2.5000e-04
# Epoch 36/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1612 - MAE: 0.2747 - RMSE: 0.4014 - val_loss: 0.2274 - val_MAE: 0.3418 - val_RMSE: 0.4769 - lr: 2.5000e-04
# Epoch 37/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1610 - MAE: 0.2742 - RMSE: 0.4012 - val_loss: 0.2218 - val_MAE: 0.3328 - val_RMSE: 0.4710 - lr: 1.2500e-04
# Epoch 38/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1606 - MAE: 0.2737 - RMSE: 0.4008 - val_loss: 0.2214 - val_MAE: 0.3292 - val_RMSE: 0.4705 - lr: 1.2500e-04
# Epoch 39/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1605 - MAE: 0.2743 - RMSE: 0.4006 - val_loss: 0.2215 - val_MAE: 0.3242 - val_RMSE: 0.4707 - lr: 1.2500e-04
# Epoch 40/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1602 - MAE: 0.2732 - RMSE: 0.4003 - val_loss: 0.2213 - val_MAE: 0.3283 - val_RMSE: 0.4704 - lr: 1.2500e-04
# Epoch 41/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1602 - MAE: 0.2719 - RMSE: 0.4002 - val_loss: 0.2213 - val_MAE: 0.3336 - val_RMSE: 0.4704 - lr: 1.2500e-04
# Epoch 42/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1600 - MAE: 0.2737 - RMSE: 0.4000 - val_loss: 0.2213 - val_MAE: 0.3303 - val_RMSE: 0.4704 - lr: 1.2500e-04
# Epoch 43/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1608 - MAE: 0.2739 - RMSE: 0.4010 - val_loss: 0.2220 - val_MAE: 0.3318 - val_RMSE: 0.4711 - lr: 1.2500e-04
# Epoch 44/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1603 - MAE: 0.2735 - RMSE: 0.4004 - val_loss: 0.2215 - val_MAE: 0.3336 - val_RMSE: 0.4707 - lr: 1.2500e-04
# Epoch 45/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1601 - MAE: 0.2733 - RMSE: 0.4001 - val_loss: 0.2226 - val_MAE: 0.3328 - val_RMSE: 0.4718 - lr: 1.2500e-04
# Epoch 46/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1602 - MAE: 0.2729 - RMSE: 0.4002 - val_loss: 0.2217 - val_MAE: 0.3318 - val_RMSE: 0.4708 - lr: 1.2500e-04
# Epoch 47/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1598 - MAE: 0.2723 - RMSE: 0.3997 - val_loss: 0.2222 - val_MAE: 0.3341 - val_RMSE: 0.4714 - lr: 6.2500e-05
# Epoch 48/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1597 - MAE: 0.2733 - RMSE: 0.3996 - val_loss: 0.2210 - val_MAE: 0.3281 - val_RMSE: 0.4701 - lr: 6.2500e-05
# Epoch 49/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1602 - MAE: 0.2728 - RMSE: 0.4002 - val_loss: 0.2212 - val_MAE: 0.3340 - val_RMSE: 0.4704 - lr: 6.2500e-05
# Epoch 50/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1600 - MAE: 0.2737 - RMSE: 0.4000 - val_loss: 0.2206 - val_MAE: 0.3302 - val_RMSE: 0.4697 - lr: 6.2500e-05
# Epoch 51/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1594 - MAE: 0.2721 - RMSE: 0.3992 - val_loss: 0.2219 - val_MAE: 0.3328 - val_RMSE: 0.4711 - lr: 6.2500e-05
# Epoch 52/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1595 - MAE: 0.2724 - RMSE: 0.3994 - val_loss: 0.2210 - val_MAE: 0.3297 - val_RMSE: 0.4701 - lr: 6.2500e-05
# Epoch 53/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1597 - MAE: 0.2738 - RMSE: 0.3996 - val_loss: 0.2212 - val_MAE: 0.3248 - val_RMSE: 0.4703 - lr: 6.2500e-05
# Epoch 54/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1596 - MAE: 0.2716 - RMSE: 0.3994 - val_loss: 0.2229 - val_MAE: 0.3376 - val_RMSE: 0.4721 - lr: 6.2500e-05
# Epoch 55/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1594 - MAE: 0.2730 - RMSE: 0.3993 - val_loss: 0.2206 - val_MAE: 0.3290 - val_RMSE: 0.4697 - lr: 6.2500e-05
# Epoch 56/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1592 - MAE: 0.2713 - RMSE: 0.3990 - val_loss: 0.2207 - val_MAE: 0.3310 - val_RMSE: 0.4698 - lr: 3.1250e-05
# Epoch 57/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1591 - MAE: 0.2719 - RMSE: 0.3988 - val_loss: 0.2208 - val_MAE: 0.3304 - val_RMSE: 0.4699 - lr: 3.1250e-05
# Epoch 58/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1594 - MAE: 0.2737 - RMSE: 0.3992 - val_loss: 0.2213 - val_MAE: 0.3254 - val_RMSE: 0.4704 - lr: 3.1250e-05
# Epoch 59/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1593 - MAE: 0.2721 - RMSE: 0.3992 - val_loss: 0.2206 - val_MAE: 0.3291 - val_RMSE: 0.4697 - lr: 3.1250e-05
# Epoch 60/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1590 - MAE: 0.2718 - RMSE: 0.3988 - val_loss: 0.2212 - val_MAE: 0.3314 - val_RMSE: 0.4703 - lr: 3.1250e-05
# Epoch 00060: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('checkpoints/Seq2Seq_LSTM.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]


    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]

#     # Present results
#     #
#     print('Horizon: ', i+1)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f RMSE %5.2f SMAPE: %5.2f R2: %.2f' % (i+1, MAE, RMSE, SMAPE, R2) )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------
# Horizon:  1 MAE 15.72 RMSE 24.37 SMAPE:  7.70 R2: 0.84
# Horizon:  2 MAE 25.63 RMSE 37.38 SMAPE: 12.64 R2: 0.64

# %% [markdown]
# ### Reliability evaluation

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
            
            

            
    from scipy                         import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------

# %% [markdown]
# ## Visualization of predictions

# %%
Prices = pd.DataFrame( [] )

Prices[targetSeries] = testY.flatten()
Prices['Prediction'] = pred.flatten()


# Plot results
#
plt.figure( figsize = (20, 4) );
#
Prices[ targetSeries ][:200].plot(color = 'tab:blue', marker = 'o')
Prices[ 'Prediction' ][:200].plot(color = 'tab:orange', marker = 'o')
plt.show();

# %% [markdown]
# ### Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [66, 62, 192, 448, 477, 1035, 34, 408, 860]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.grid()

    plt.plot(testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Future values', 'Prediction'], frameon = False, fontsize = 12)
    plt.ylim([90, 260])
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Seq2Seq_LSTM'] = pred.flatten()

Outputs.to_csv('Predictions/Seq2Seq_LSTM.csv')
