# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    2
#
epochs     =  500
batch_size =  128

Transformation = True

# %% [markdown]
# # Importing data

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Data concern the concentration from a mine in Norway
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

 

# # Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'



# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.35 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %%
# # Parameters
# #
# filename   = '../Data/D-6-It.csv'

# Transformation  = True
# Scaling         = 'Standard'




# # Start timer
# #
# start = time.time()

# # Load data
# #
# df = pd.read_csv(filename, 
#                  sep = ',')


# # Rename columns
# #
# df = df.rename(columns = {'created_at' : 'Date',
#                           'field1' : 'Temperature',
#                           'field2' : 'Humidity',
#                           'field3' : 'PM2.5',
#                           'field4' : 'PM10',
#                           'field5' : 'NO2',
#                           'field6' : 'CO',
#                           'field7' : 'NH4',})



# # End timer
# #
# print('[INFO] Time: %.2f' % (time.time() - start))

# df.head( 3 )

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)



df = df.resample('10min').mean() 
df = pd.DataFrame( df[ ['CO'] ] )
# df = pd.DataFrame( df[ ['NO2', 'CO'] ] )
# df = pd.DataFrame( df[ ['Temperature', 'Humidity', 'NO2', 'CO'] ] )


df.head(3)
# Out:
#                              CO
# Date
# 2022-02-19 00:00:00  240.710526
# 2022-02-19 00:10:00  227.473684
# 2022-02-19 00:20:00  229.526316

# %%
# Set target series/Series which will be forecasted
# 
targetSeries = df.columns[-1]

# Set all other utilized features
# Features = df.columns[:-1]

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ] 
df_test  = df[ idx: ]

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  8558
# Testing:   2140

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Testing'], fontsize = 12, frameon = False);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(abs( -df.min().min() ) + 1.0, 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)

    # # Transformation parameter
    # #
    # d = {'parameter': VALUE}

    # import json
    # with open('checkpoints/Transformation.json', 'w') as fp:
    #     json.dump(d, fp)
    # print('[INFO] Parameters saved')

else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )


# # Save Scaler
# #
# import pickle
# filename = 'checkpoints/Target_scaler.pkl'
# pickle.dump(scaler, open(filename, 'wb'))
# print('[INFO] Target scaler saved in ', filename)

# %% [markdown]
# ### Include date/time features

# %%
# df_train['Time (sin)'] = np.sin( df_train.index.hour + df_train.index.minute / 60 )
# df_train['Time (cos)'] = np.cos( df_train.index.hour + df_train.index.minute / 60 )
# #
# df_test['Time (sin)']  = np.sin( df_test.index.hour + df_test.index.minute / 60 )
# df_test['Time (cos)']  = np.cos( df_test.index.hour + df_test.index.minute / 60 )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Check for NaN values
        if (df[i:i + Lag + Horizon].dropna().shape[0] != df[i:i + Lag + Horizon].shape[0]): continue
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1)
                               

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 8545/8545 [00:08<00:00, 1059.75it/s]
# 100%|██████████| 1070/1070 [00:01<00:00, 875.61it/s]
# Training instances:     8545
# Testing instances:      1070

# %% [markdown]
# # Forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsolutePercentageError(name = "MAPE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *
# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )
# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')(Decoder)

# Output
#
# Outputs =  TimeDistributed(Dense(1, activation='linear'))( Decoder )
Outputs =  Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("checkpoints/Seq2Seq_LSTM.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 10)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 5)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = [checkpoint, earlystopping, lrs_scheduler],
                  verbose          = 1, 
                  shuffle          = True,
                  validation_split = 0.2)


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/500
# 54/54 [==============================] - 3s 22ms/step - loss: 0.6863 - MAE: 0.6745 - RMSE: 0.8284 - val_loss: 0.5781 - val_MAE: 0.6360 - val_RMSE: 0.7603 - lr: 5.0000e-04
# Epoch 2/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.3215 - MAE: 0.4368 - RMSE: 0.5670 - val_loss: 0.3522 - val_MAE: 0.4527 - val_RMSE: 0.5935 - lr: 5.0000e-04
# Epoch 3/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.2304 - MAE: 0.3522 - RMSE: 0.4801 - val_loss: 0.2992 - val_MAE: 0.4100 - val_RMSE: 0.5470 - lr: 5.0000e-04
# Epoch 4/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.2006 - MAE: 0.3188 - RMSE: 0.4479 - val_loss: 0.2640 - val_MAE: 0.3410 - val_RMSE: 0.5138 - lr: 5.0000e-04
# Epoch 5/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1862 - MAE: 0.2971 - RMSE: 0.4315 - val_loss: 0.2528 - val_MAE: 0.3639 - val_RMSE: 0.5028 - lr: 5.0000e-04
# Epoch 6/500
# 54/54 [==============================] - 1s 17ms/step - loss: 0.1865 - MAE: 0.3030 - RMSE: 0.4318 - val_loss: 0.2483 - val_MAE: 0.3448 - val_RMSE: 0.4983 - lr: 5.0000e-04
# Epoch 7/500
# 54/54 [==============================] - 1s 16ms/step - loss: 0.1838 - MAE: 0.2974 - RMSE: 0.4287 - val_loss: 0.2444 - val_MAE: 0.3365 - val_RMSE: 0.4944 - lr: 5.0000e-04
# Epoch 8/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1817 - MAE: 0.2974 - RMSE: 0.4263 - val_loss: 0.2523 - val_MAE: 0.3610 - val_RMSE: 0.5023 - lr: 5.0000e-04
# Epoch 9/500
# 54/54 [==============================] - 1s 17ms/step - loss: 0.1784 - MAE: 0.2923 - RMSE: 0.4223 - val_loss: 0.2441 - val_MAE: 0.3314 - val_RMSE: 0.4941 - lr: 5.0000e-04
# Epoch 10/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1813 - MAE: 0.2969 - RMSE: 0.4258 - val_loss: 0.2406 - val_MAE: 0.3277 - val_RMSE: 0.4905 - lr: 5.0000e-04
# Epoch 11/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1763 - MAE: 0.2890 - RMSE: 0.4199 - val_loss: 0.2370 - val_MAE: 0.3440 - val_RMSE: 0.4868 - lr: 5.0000e-04
# Epoch 12/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1776 - MAE: 0.2921 - RMSE: 0.4214 - val_loss: 0.2413 - val_MAE: 0.3363 - val_RMSE: 0.4912 - lr: 5.0000e-04
# Epoch 13/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1766 - MAE: 0.2910 - RMSE: 0.4202 - val_loss: 0.2390 - val_MAE: 0.3450 - val_RMSE: 0.4889 - lr: 5.0000e-04
# Epoch 14/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1767 - MAE: 0.2907 - RMSE: 0.4204 - val_loss: 0.2342 - val_MAE: 0.3361 - val_RMSE: 0.4840 - lr: 5.0000e-04
# Epoch 15/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1736 - MAE: 0.2874 - RMSE: 0.4167 - val_loss: 0.2408 - val_MAE: 0.3346 - val_RMSE: 0.4907 - lr: 5.0000e-04
# Epoch 16/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1763 - MAE: 0.2899 - RMSE: 0.4199 - val_loss: 0.2344 - val_MAE: 0.3330 - val_RMSE: 0.4842 - lr: 5.0000e-04
# Epoch 17/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1731 - MAE: 0.2863 - RMSE: 0.4160 - val_loss: 0.2402 - val_MAE: 0.3351 - val_RMSE: 0.4901 - lr: 5.0000e-04
# Epoch 18/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1762 - MAE: 0.2910 - RMSE: 0.4198 - val_loss: 0.2387 - val_MAE: 0.3448 - val_RMSE: 0.4886 - lr: 5.0000e-04
# Epoch 19/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1737 - MAE: 0.2865 - RMSE: 0.4167 - val_loss: 0.2385 - val_MAE: 0.3486 - val_RMSE: 0.4884 - lr: 5.0000e-04
# Epoch 20/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.
500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1693 - MAE: 0.2825 - RMSE: 0.4115 - val_loss: 0.2309 - val_MAE: 0.3310 - val_RMSE: 0.4805 - lr: 1.2500e-04
# Epoch 37/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1698 - MAE: 0.2825 - RMSE: 0.4121 - val_loss: 0.2307 - val_MAE: 0.3302 - val_RMSE: 0.4803 - lr: 1.2500e-04
# Epoch 38/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1694 - MAE: 0.2819 - RMSE: 0.4116 - val_loss: 0.2318 - val_MAE: 0.3285 - val_RMSE: 0.4814 - lr: 1.2500e-04
# Epoch 39/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1695 - MAE: 0.2831 - RMSE: 0.4117 - val_loss: 0.2344 - val_MAE: 0.3262 - val_RMSE: 0.4842 - lr: 1.2500e-04
# Epoch 40/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1689 - MAE: 0.2813 - RMSE: 0.4110 - val_loss: 0.2323 - val_MAE: 0.3279 - val_RMSE: 0.4820 - lr: 1.2500e-04
# Epoch 41/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1690 - MAE: 0.2807 - RMSE: 0.4111 - val_loss: 0.2304 - val_MAE: 0.3355 - val_RMSE: 0.4800 - lr: 1.2500e-04
# Epoch 42/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1690 - MAE: 0.2825 - RMSE: 0.4111 - val_loss: 0.2315 - val_MAE: 0.3287 - val_RMSE: 0.4811 - lr: 1.2500e-04
# Epoch 43/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1702 - MAE: 0.2831 - RMSE: 0.4125 - val_loss: 0.2304 - val_MAE: 0.3292 - val_RMSE: 0.4800 - lr: 1.2500e-04
# Epoch 44/500
# 54/54 [==============================] - 1s 15ms/step - loss: 0.1695 - MAE: 0.2829 - RMSE: 0.4118 - val_loss: 0.2314 - val_MAE: 0.3313 - val_RMSE: 0.4811 - lr: 1.2500e-04
# Epoch 45/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1689 - MAE: 0.2819 - RMSE: 0.4110 - val_loss: 0.2307 - val_MAE: 0.3303 - val_RMSE: 0.4803 - lr: 1.2500e-04
# Epoch 46/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1693 - MAE: 0.2815 - RMSE: 0.4114 - val_loss: 0.2313 - val_MAE: 0.3362 - val_RMSE: 0.4809 - lr: 1.2500e-04
# Epoch 47/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1689 - MAE: 0.2817 - RMSE: 0.4110 - val_loss: 0.2302 - val_MAE: 0.3325 - val_RMSE: 0.4797 - lr: 6.2500e-05
# Epoch 48/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1687 - MAE: 0.2820 - RMSE: 0.4107 - val_loss: 0.2316 - val_MAE: 0.3277 - val_RMSE: 0.4813 - lr: 6.2500e-05
# Epoch 49/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1694 - MAE: 0.2817 - RMSE: 0.4115 - val_loss: 0.2307 - val_MAE: 0.3363 - val_RMSE: 0.4804 - lr: 6.2500e-05
# Epoch 50/500
# 54/54 [==============================] - 1s 17ms/step - loss: 0.1688 - MAE: 0.2823 - RMSE: 0.4108 - val_loss: 0.2325 - val_MAE: 0.3307 - val_RMSE: 0.4822 - lr: 6.2500e-05
# Epoch 51/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1684 - MAE: 0.2809 - RMSE: 0.4103 - val_loss: 0.2300 - val_MAE: 0.3297 - val_RMSE: 0.4796 - lr: 6.2500e-05
# Epoch 52/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1683 - MAE: 0.2809 - RMSE: 0.4102 - val_loss: 0.2342 - val_MAE: 0.3312 - val_RMSE: 0.4840 - lr: 6.2500e-05
# Epoch 53/500
# 54/54 [==============================] - 1s 11ms/step - loss: 0.1686 - MAE: 0.2822 - RMSE: 0.4106 - val_loss: 0.2344 - val_MAE: 0.3268 - val_RMSE: 0.4842 - lr: 6.2500e-05
# Epoch 54/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1683 - MAE: 0.2802 - RMSE: 0.4103 - val_loss: 0.2301 - val_MAE: 0.3346 - val_RMSE: 0.4797 - lr: 6.2500e-05
# Epoch 55/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1683 - MAE: 0.2817 - RMSE: 0.4103 - val_loss: 0.2305 - val_MAE: 0.3288 - val_RMSE: 0.4801 - lr: 6.2500e-05
# Epoch 56/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1686 - MAE: 0.2807 - RMSE: 0.4106 - val_loss: 0.2300 - val_MAE: 0.3347 - val_RMSE: 0.4796 - lr: 6.2500e-05
# Epoch 57/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1681 - MAE: 0.2807 - RMSE: 0.4100 - val_loss: 0.2300 - val_MAE: 0.3297 - val_RMSE: 0.4796 - lr: 3.1250e-05
# Epoch 58/500
# 54/54 [==============================] - 1s 13ms/step - loss: 0.1684 - MAE: 0.2824 - RMSE: 0.4103 - val_loss: 0.2352 - val_MAE: 0.3287 - val_RMSE: 0.4849 - lr: 3.1250e-05
# Epoch 59/500
# 54/54 [==============================] - 1s 14ms/step - loss: 0.1684 - MAE: 0.2812 - RMSE: 0.4103 - val_loss: 0.2307 - val_MAE: 0.3276 - val_RMSE: 0.4803 - lr: 3.1250e-05
# Epoch 60/500
# 54/54 [==============================] - 1s 12ms/step - loss: 0.1680 - MAE: 0.2804 - RMSE: 0.4099 - val_loss: 0.2301 - val_MAE: 0.3304 - val_RMSE: 0.4797 - lr: 3.1250e-05
# Epoch 61/500
# 54/54 [==============================] - 1s 17ms/step - loss: 0.1679 - MAE: 0.2811 - RMSE: 0.4098 - val_loss: 0.2304 - val_MAE: 0.3281 - val_RMSE: 0.4800 - lr: 3.1250e-05
# Epoch 00061: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('checkpoints/Seq2Seq_LSTM.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]


    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]

    # Present results
    #
#     print('Horizon: ', i+1)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f RMSE %5.2f SMAPE: %5.2f R2: %.2f' % (i+1, MAE, RMSE, SMAPE, R2) )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------
# Horizon:  1 MAE 15.64 RMSE 24.47 SMAPE:  7.58 R2: 0.84
# Horizon:  2 MAE 25.86 RMSE 37.50 SMAPE: 12.78 R2: 0.64

# %% [markdown]
# ### Reliability evaluation

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
            
            

            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  CO
# ------------------------------------------------

# %% [markdown]
# ## Visualization of predictions

# %%
Prices = pd.DataFrame( [] )

Prices[targetSeries] = testY.flatten()
Prices['Prediction'] = pred.flatten()


# Plot results
#
plt.figure( figsize = (20, 4) );
#
Prices[ targetSeries ][:200].plot(color = 'tab:blue', marker = 'o')
Prices[ 'Prediction' ][:200].plot(color = 'tab:orange', marker = 'o')
plt.show();

# %% [markdown]
# ### Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [66, 62, 192, 448, 477, 1035, 34, 408, 860]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.grid()

    plt.plot(testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Future values', 'Prediction'], frameon = False, fontsize = 12)
    plt.ylim([90, 260])
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Seq2Seq_LSTM'] = pred.flatten()

Outputs.to_csv('Predictions/Seq2Seq_LSTM.csv')
