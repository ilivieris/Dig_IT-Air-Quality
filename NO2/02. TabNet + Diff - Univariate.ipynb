# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import random
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler



# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# TabNet library
#
from pytorch_tabnet.tab_model import TabNetRegressor


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.plot_scatter       import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        =   12
Horizon    =    4

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.47 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
df = pd.DataFrame( df['NO2'] )
df.head(3)
# Out:
#                             NO2
# Date
# 2022-02-19 00:00:00  186.210526
# 2022-02-19 00:05:00  151.052632
# 2022-02-19 00:10:00  135.315789

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train.plot(ax=ax, color='tab:blue' )
df_test.plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scaler = MinMaxScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scaler = RobustScaler()
     
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
           
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    # Set scaler
    #
    scaler = StandardScaler()

    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):

        # Instances: Lag-d differences
        Instance  = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ][i:(i+Lag-1)]).to_list()
#         # Time
#         Instance.append( df.index[i+Lag-1].hour + df.index[i+Lag-1].minute / 60) 
        # Current value
        Instance.append( df[ targetSeries ].to_numpy()[i+Lag-1] )

           
        

        # Append instance
        dataX.append( Instance ) 
                
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )

        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df           = df_train, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = Horizon,)

testX,  testY  = create_dataset(df           = df_test, 
                                Lag          = Lag, 
                                Horizon      = Horizon, 
                                targetSeries = targetSeries,
                                overlap      = 1,)

print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 4276/4276 [00:01<00:00, 3945.13it/s]
# 100%|██████████| 4277/4277 [00:01<00:00, 3785.36it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 12), (4276, 4))

# %% [markdown]
# # Forecasting model: TabNet

# %% [markdown]
# ## Setup model

# %%
model = TabNetRegressor(verbose = 1, 
                        seed    = 42)
# Out:
# Device used : cpu

# %% [markdown]
# ## Training process

# %%
import torch.nn as nn

# Start clock
#
start = time.time()

# Train model
#
model.fit(X_train = trainX, 
          y_train = trainY,
          loss_fn = nn.MSELoss(), # nn.L1Loss(), nn.MSELoss()
          #
          eval_set    = [(testX, testY)],
          batch_size  = 32,
          num_workers = 0,
          patience    = 200, 
          max_epochs  = 2000,
          eval_metric = ['rmse'])

# Terminate clock
#
stop = time.time()

print('[INFO] Time %.2f' % (stop - start))
# Out:
# epoch 0  | loss: 0.19626 | val_0_rmse: 0.55167 |  0:00:04s
# epoch 1  | loss: 0.13526 | val_0_rmse: 0.55545 |  0:00:07s
# epoch 2  | loss: 0.13335 | val_0_rmse: 0.55448 |  0:00:11s
# epoch 3  | loss: 0.13159 | val_0_rmse: 0.55317 |  0:00:15s
# epoch 4  | loss: 0.13222 | val_0_rmse: 0.54851 |  0:00:18s
# epoch 5  | loss: 0.13151 | val_0_rmse: 0.5505  |  0:00:22s
# epoch 6  | loss: 0.13094 | val_0_rmse: 0.54962 |  0:00:26s
# epoch 7  | loss: 0.13067 | val_0_rmse: 0.55029 |  0:00:30s
# epoch 8  | loss: 0.13026 | val_0_rmse: 0.55452 |  0:00:33s
# epoch 9  | loss: 0.13236 | val_0_rmse: 0.55258 |  0:00:36s
# epoch 10 | loss: 0.13129 | val_0_rmse: 0.54552 |  0:00:39s
# epoch 11 | loss: 0.12999 | val_0_rmse: 0.54709 |  0:00:43s
# epoch 12 | loss: 0.13019 | val_0_rmse: 0.54827 |  0:00:46s
# epoch 13 | loss: 0.12891 | val_0_rmse: 0.54785 |  0:00:50s
# epoch 14 | loss: 0.12954 | val_0_rmse: 0.5461  |  0:00:53s
# epoch 15 | loss: 0.12933 | val_0_rmse: 0.54495 |  0:00:57s
# epoch 16 | loss: 0.12729 | val_0_rmse: 0.54458 |  0:01:00s
# epoch 17 | loss: 0.12746 | val_0_rmse: 0.54518 |  0:01:04s
# epoch 18 | loss: 0.12968 | val_0_rmse: 0.54741 |  0:01:08s
# epoch 19 | loss: 0.1289  | val_0_rmse: 0.54877 |  0:01:11s
# epoch 20 | loss: 0.12802 | val_0_rmse: 0.54386 |  0:01:15s
# epoch 21 | loss: 0.12776 | val_0_rmse: 0.54216 |  0:01:18s
# epoch 22 | loss: 0.12754 | val_0_rmse: 0.54623 |  0:01:22s
# epoch 23 | loss: 0.1289  | val_0_rmse: 0.54659 |  0:01:25s
# epoch 24 | loss: 0.12805 | val_0_rmse: 0.54574 |  0:01:28s
# epoch 25 | loss: 0.12789 | val_0_rmse: 0.54595 |  0:01:31s
# epoch 26 | loss: 0.12685 | val_0_rmse: 0.54512 |  0:01:34s
# epoch 27 | loss: 0.12694 | val_0_rmse: 0.54351 |  0:01:38s
# epoch 28 | loss: 0.12756 | val_0_rmse: 0.54963 |  0:01:41s
# epoch 29 | loss: 0.12884 | val_0_rmse: 0.54523 |  0:01:44s
# epoch 30 | loss: 0.12888 | val_0_rmse: 0.5435  |  0:01:47s
# epoch 31 | loss: 0.12998 | val_0_rmse: 0.5498  |  0:01:51s
# epoch 32 | loss: 0.12856 | val_0_rmse: 0.5428  |  0:01:54s
# epoch 33 | loss: 0.12859 | val_0_rmse: 0.54523 |  0:01:57s
# epoch 34 | loss: 0.12861 | val_0_rmse: 0.55    |  0:02:00s
# epoch 35 | loss: 0.12751 | val_0_rmse: 0.54453 |  0:02:03s
# epoch 36 | loss: 0.127   | val_0_rmse: 0.54561 |  0:02:07s
# epoch 37 | loss: 0.1269  | val_0_rmse: 0.54782 |  0:02:10s
# epoch 38 | loss: 0.12743 | val_0_rmse: 0.55044 |  0:02:13s
# epoch 39 | loss: 0.12657 | val_0_rmse: 0.54573 |  0:02:16s
# epoch 40 | loss: 0.12706 | val_0_rmse: 0.54901 |  0:02:19s
# epoch 41 | loss: 0.12731 | val_0_rmse: 0.54187 |  0:02:23s
# epoch 42 | loss: 0.1275  | val_0_rmse: 0.54353 |  0:02:26s
# epoch 43 | loss: 0.12749 | val_0_rmse: 0.54209 |  0:02:29s
# epoch 44 | loss: 0.12703 | val_0_rmse: 0.5463  |  0:02:32s
# epoch 45 | loss: 0.12615 | val_0_rmse: 0.54872 |  0:02:34s
# epoch 46 | loss: 0.12678 | val_0_rmse: 0.54102 |  0:02:37s
# epoch 47 | loss: 0.12659 | val_0_rmse: 0.54557 |  0:02:40s
# epoch 48 | loss: 0.12663 | val_0_rmse: 0.5462  |  0:02:43s
# epoch 49 | loss: 0.12626 | val_0_rmse: 0.54499 |  0:02:46s
# epoch 50 | loss: 0.12761 | val_0_rmse: 0.54444 |  0:02:49s
# epoch 51 | loss: 0.12661 | val_0_rmse: 0.54998 |  0:02:51s
# epoch 52 | loss: 0.12693 | val_0_rmse: 0.54174 |  0:02:54s
# epoch 53 | loss: 0.12684 | val_0_rmse: 0.54578 |  0:02:57s
# epoch 54 | loss: 0.12709 | val_0_rmse: 0.5497  |  0:03:00s
# epoch 55 | loss: 0.12659 | val_0_rmse: 0.54286 |  0:03:03s
# epoch 56 | loss: 0.12637 | val_0_rmse: 0.54542 |  0:03:06s
# epoch 57 | loss: 0.12674 | val_0_rmse: 0.54456 |  0:03:09s
# epoch 58 | loss: 0.12683 | val_0_rmse: 0.54471 |  0:03:11s
# epoch 59 | loss: 0.12659 | val_0_rmse: 0.54291 |  0:03:14s
# epoch 60 | loss: 0.12666 | val_0_rmse: 0.54112 |  0:03:17s
# epoch 61 | loss: 0.12621 | val_0_rmse: 0.54935 |  0:03:20s
# epoch 62 | loss: 0.12736 | val_0_rmse: 0.54443 |  0:03:23s
# epoch 63 | loss: 0.12595 | val_0_rmse: 0.54308 |  0:03:26s
# epoch 64 | loss: 0.12676 | val_0_rmse: 0.54203 |  0:03:29s
# epoch 65 | loss: 0.12658 | val_0_rmse: 0.54068 |  0:03:31s
# epoch 66 | loss: 0.12694 | val_0_rmse: 0.54172 |  0:03:34s
# epoch 67 | loss: 0.12691 | val_0_rmse: 0.54392 |  0:03:37s
# epoch 68 | loss: 0.1261  | val_0_rmse: 0.54363 |  0:03:40s
# epoch 69 | loss: 0.12734 | val_0_rmse: 0.54454 |  0:03:43s
# epoch 70 | loss: 0.12658 | val_0_rmse: 0.54677 |  0:03:46s
# epoch 71 | loss: 0.12774 | val_0_rmse: 0.54253 |  0:03:49s
# epoch 72 | loss: 0.12627 | val_0_rmse: 0.54422 |  0:03:51s
# epoch 73 | loss: 0.12636 | val_0_rmse: 0.54139 |  0:03:54s
# epoch 74 | loss: 0.12589 | val_0_rmse: 0.5435  |  0:03:57s
# epoch 75 | loss: 0.12691 | val_0_rmse: 0.54632 |  0:04:00s
# epoch 76 | loss: 0.12631 | val_0_rmse: 0.54512 |  0:04:03s
# epoch 77 | loss: 0.126   | val_0_rmse: 0.54369 |  0:04:06s
# epoch 78 | loss: 0.12631 | val_0_rmse: 0.5445  |  0:04:09s
# epoch 79 | loss: 0.12745 | val_0_rmse: 0.54718 |  0:04:11s
# epoch 80 | loss: 0.12631 | val_0_rmse: 0.54441 |  0:04:14s
# epoch 81 | loss: 0.12708 | val_0_rmse: 0.54677 |  0:04:17s
# epoch 82 | loss: 0.12647 | val_0_rmse: 0.54327 |  0:04:20s
# epoch 83 | loss: 0.12672 | val_0_rmse: 0.55051 |  0:04:23s
# epoch 84 | loss: 0.12695 | val_0_rmse: 0.54669 |  0:04:26s
# epoch 85 | loss: 0.12639 | val_0_rmse: 0.54353 |  0:04:28s
# epoch 86 | loss: 0.12647 | val_0_rmse: 0.5449  |  0:04:31s
# epoch 87 | loss: 0.12677 | val_0_rmse: 0.54406 |  0:04:34s
# epoch 88 | loss: 0.12697 | val_0_rmse: 0.54446 |  0:04:37s
# epoch 89 | loss: 0.12695 | val_0_rmse: 0.54665 |  0:04:40s
# epoch 90 | loss: 0.12699 | val_0_rmse: 0.54191 |  0:04:43s
# epoch 91 | loss: 0.12635 | val_0_rmse: 0.54339 |  0:04:45s
# epoch 92 | loss: 0.12683 | val_0_rmse: 0.54856 |  0:04:48s
# epoch 93 | loss: 0.12713 | val_0_rmse: 0.5475  |  0:04:51s
# epoch 94 | loss: 0.12708 | val_0_rmse: 0.54366 |  0:04:54s
# epoch 95 | loss: 0.12674 | val_0_rmse: 0.54545 |  0:04:57s
# epoch 96 | loss: 0.12646 | val_0_rmse: 0.54317 |  0:05:00s
# epoch 97 | loss: 0.12654 | val_0_rmse: 0.54343 |  0:05:02s
# epoch 98 | loss: 0.12645 | val_0_rmse: 0.55042 |  0:05:05s
# epoch 99 | loss: 0.1263  | val_0_rmse: 0.54581 |  0:05:08s
# epoch 100| loss: 0.12646 | val_0_rmse: 0.54864 |  0:05:11s
# epoch 101| loss: 0.1263  | val_0_rmse: 0.543   |  0:05:14s
# epoch 102| loss: 0.12687 | val_0_rmse: 0.54679 |  0:05:17s
# epoch 103| loss: 0.1269  | val_0_rmse: 0.545   |  0:05:20s
# epoch 104| loss: 0.12668 | val_0_rmse: 0.54467 |  0:05:22s
# epoch 105| loss: 0.12696 | val_0_rmse: 0.54497 |  0:05:25s
# epoch 106| loss: 0.12615 | val_0_rmse: 0.54457 |  0:05:28s
# epoch 107| loss: 0.12689 | val_0_rmse: 0.54292 |  0:05:31s
# epoch 108| loss: 0.12675 | val_0_rmse: 0.54793 |  0:05:34s
# epoch 109| loss: 0.12589 | val_0_rmse: 0.54608 |  0:05:37s
# epoch 110| loss: 0.12648 | val_0_rmse: 0.54822 |  0:05:40s
# epoch 111| loss: 0.12624 | val_0_rmse: 0.54535 |  0:05:42s
# epoch 112| loss: 0.12678 | val_0_rmse: 0.54214 |  0:05:45s
# epoch 113| loss: 0.12671 | val_0_rmse: 0.54369 |  0:05:48s
# epoch 114| loss: 0.12533 | val_0_rmse: 0.54492 |  0:05:51s
# epoch 115| loss: 0.12631 | val_0_rmse: 0.5449  |  0:05:54s
# epoch 116| loss: 0.1266  | val_0_rmse: 0.54604 |  0:05:57s
# epoch 117| loss: 0.12675 | val_0_rmse: 0.54609 |  0:05:59s
# epoch 118| loss: 0.12647 | val_0_rmse: 0.54268 |  0:06:02s
# epoch 119| loss: 0.12596 | val_0_rmse: 0.55033 |  0:06:05s
# epoch 120| loss: 0.12616 | val_0_rmse: 0.54986 |  0:06:08s
# epoch 121| loss: 0.12602 | val_0_rmse: 0.54457 |  0:06:11s
# epoch 122| loss: 0.12598 | val_0_rmse: 0.54534 |  0:06:14s
# epoch 123| loss: 0.12624 | val_0_rmse: 0.54833 |  0:06:17s
# epoch 124| loss: 0.12701 | val_0_rmse: 0.54521 |  0:06:19s
# epoch 125| loss: 0.12631 | val_0_rmse: 0.54607 |  0:06:22s
# epoch 126| loss: 0.12645 | val_0_rmse: 0.54634 |  0:06:25s
# epoch 127| loss: 0.12659 | val_0_rmse: 0.54425 |  0:06:28s
# epoch 128| loss: 0.12668 | val_0_rmse: 0.54274 |  0:06:31s
# epoch 129| loss: 0.12667 | val_0_rmse: 0.54583 |  0:06:34s
# epoch 130| loss: 0.12701 | val_0_rmse: 0.54409 |  0:06:36s
# epoch 131| loss: 0.12566 | val_0_rmse: 0.54667 |  0:06:39s
# epoch 132| loss: 0.12674 | val_0_rmse: 0.54553 |  0:06:42s
# epoch 133| loss: 0.12523 | val_0_rmse: 0.54966 |  0:06:45s
# epoch 134| loss: 0.12636 | val_0_rmse: 0.54333 |  0:06:48s
# epoch 135| loss: 0.12589 | val_0_rmse: 0.551   |  0:06:51s
# epoch 136| loss: 0.12602 | val_0_rmse: 0.54425 |  0:06:53s
# epoch 137| loss: 0.12643 | val_0_rmse: 0.55213 |  0:06:56s
# epoch 138| loss: 0.12634 | val_0_rmse: 0.54883 |  0:06:59s
# epoch 139| loss: 0.12669 | val_0_rmse: 0.54486 |  0:07:02s
# epoch 140| loss: 0.12685 | val_0_rmse: 0.54716 |  0:07:05s
# epoch 141| loss: 0.12657 | val_0_rmse: 0.54829 |  0:07:08s
# epoch 142| loss: 0.1265  | val_0_rmse: 0.54611 |  0:07:10s
# epoch 143| loss: 0.12654 | val_0_rmse: 0.54688 |  0:07:13s
# epoch 144| loss: 0.12629 | val_0_rmse: 0.54516 |  0:07:16s
# epoch 145| loss: 0.12624 | val_0_rmse: 0.54451 |  0:07:19s
# epoch 146| loss: 0.12591 | val_0_rmse: 0.54713 |  0:07:22s
# epoch 147| loss: 0.1267  | val_0_rmse: 0.5439  |  0:07:25s
# epoch 148| loss: 0.12618 | val_0_rmse: 0.54334 |  0:07:27s
# epoch 149| loss: 0.12645 | val_0_rmse: 0.5452  |  0:07:30s
# epoch 150| loss: 0.12604 | val_0_rmse: 0.54645 |  0:07:33s
# epoch 151| loss: 0.12609 | val_0_rmse: 0.54471 |  0:07:35s
# epoch 152| loss: 0.12583 | val_0_rmse: 0.54722 |  0:07:38s
# epoch 153| loss: 0.12631 | val_0_rmse: 0.54631 |  0:07:41s
# epoch 154| loss: 0.12607 | val_0_rmse: 0.54751 |  0:07:44s
# epoch 155| loss: 0.12625 | val_0_rmse: 0.54764 |  0:07:46s
# epoch 156| loss: 0.12633 | val_0_rmse: 0.54731 |  0:07:49s
# epoch 157| loss: 0.12648 | val_0_rmse: 0.54749 |  0:07:52s
# epoch 158| loss: 0.12589 | val_0_rmse: 0.54689 |  0:07:54s
# epoch 159| loss: 0.12627 | val_0_rmse: 0.54653 |  0:07:57s
# epoch 160| loss: 0.12707 | val_0_rmse: 0.54659 |  0:08:00s
# epoch 161| loss: 0.12571 | val_0_rmse: 0.5458  |  0:08:02s
# epoch 162| loss: 0.1263  | val_0_rmse: 0.54366 |  0:08:05s
# epoch 163| loss: 0.12682 | val_0_rmse: 0.54516 |  0:08:08s
# epoch 164| loss: 0.12609 | val_0_rmse: 0.54438 |  0:08:10s
# epoch 165| loss: 0.12639 | val_0_rmse: 0.54464 |  0:08:13s
# epoch 166| loss: 0.12612 | val_0_rmse: 0.55039 |  0:08:16s
# epoch 167| loss: 0.1268  | val_0_rmse: 0.54444 |  0:08:18s
# epoch 168| loss: 0.12604 | val_0_rmse: 0.54769 |  0:08:21s
# epoch 169| loss: 0.12599 | val_0_rmse: 0.54615 |  0:08:24s
# epoch 170| loss: 0.12574 | val_0_rmse: 0.54378 |  0:08:27s
# epoch 171| loss: 0.1256  | val_0_rmse: 0.54536 |  0:08:29s
# epoch 172| loss: 0.12608 | val_0_rmse: 0.54901 |  0:08:32s
# epoch 173| loss: 0.12703 | val_0_rmse: 0.54526 |  0:08:35s
# epoch 174| loss: 0.12652 | val_0_rmse: 0.5454  |  0:08:37s
# epoch 175| loss: 0.12614 | val_0_rmse: 0.54993 |  0:08:40s
# epoch 176| loss: 0.12627 | val_0_rmse: 0.54725 |  0:08:43s
# epoch 177| loss: 0.12559 | val_0_rmse: 0.54442 |  0:08:45s
# epoch 178| loss: 0.12636 | val_0_rmse: 0.54633 |  0:08:48s
# epoch 179| loss: 0.12646 | val_0_rmse: 0.54442 |  0:08:51s
# epoch 180| loss: 0.12626 | val_0_rmse: 0.54542 |  0:08:53s
# epoch 181| loss: 0.12627 | val_0_rmse: 0.54645 |  0:08:56s
# epoch 182| loss: 0.12646 | val_0_rmse: 0.54774 |  0:08:59s
# epoch 183| loss: 0.12582 | val_0_rmse: 0.54869 |  0:09:01s
# epoch 184| loss: 0.12631 | val_0_rmse: 0.55174 |  0:09:04s
# epoch 185| loss: 0.12592 | val_0_rmse: 0.54554 |  0:09:07s
# epoch 186| loss: 0.12634 | val_0_rmse: 0.54885 |  0:09:09s
# epoch 187| loss: 0.12617 | val_0_rmse: 0.54667 |  0:09:12s
# epoch 188| loss: 0.12592 | val_0_rmse: 0.54795 |  0:09:14s
# epoch 189| loss: 0.12633 | val_0_rmse: 0.55001 |  0:09:17s
# epoch 190| loss: 0.12666 | val_0_rmse: 0.54791 |  0:09:19s
# epoch 191| loss: 0.12609 | val_0_rmse: 0.54707 |  0:09:22s
# epoch 192| loss: 0.12609 | val_0_rmse: 0.54778 |  0:09:24s
# epoch 193| loss: 0.12673 | val_0_rmse: 0.54451 |  0:09:26s
# epoch 194| loss: 0.12571 | val_0_rmse: 0.54439 |  0:09:29s
# epoch 195| loss: 0.12616 | val_0_rmse: 0.5426  |  0:09:31s
# epoch 196| loss: 0.12575 | val_0_rmse: 0.54293 |  0:09:34s
# epoch 197| loss: 0.12664 | val_0_rmse: 0.54687 |  0:09:36s
# epoch 198| loss: 0.12664 | val_0_rmse: 0.54494 |  0:09:39s
# epoch 199| loss: 0.12569 | val_0_rmse: 0.54494 |  0:09:41s
# epoch 200| loss: 0.12606 | val_0_rmse: 0.54333 |  0:09:44s
# epoch 201| loss: 0.12632 | val_0_rmse: 0.54551 |  0:09:46s
# epoch 202| loss: 0.12613 | val_0_rmse: 0.54878 |  0:09:49s
# epoch 203| loss: 0.12615 | val_0_rmse: 0.54651 |  0:09:51s
# epoch 204| loss: 0.12576 | val_0_rmse: 0.54457 |  0:09:53s
# epoch 205| loss: 0.12651 | val_0_rmse: 0.5469  |  0:09:56s
# epoch 206| loss: 0.1262  | val_0_rmse: 0.54721 |  0:09:58s
# epoch 207| loss: 0.12669 | val_0_rmse: 0.54583 |  0:10:01s
# epoch 208| loss: 0.12605 | val_0_rmse: 0.54677 |  0:10:03s
# epoch 209| loss: 0.12615 | val_0_rmse: 0.54466 |  0:10:06s
# epoch 210| loss: 0.12653 | val_0_rmse: 0.5455  |  0:10:08s
# epoch 211| loss: 0.12631 | val_0_rmse: 0.54728 |  0:10:11s
# epoch 212| loss: 0.12523 | val_0_rmse: 0.54493 |  0:10:13s
# epoch 213| loss: 0.12688 | val_0_rmse: 0.5471  |  0:10:16s
# epoch 214| loss: 0.1263  | val_0_rmse: 0.54637 |  0:10:18s
# epoch 215| loss: 0.12646 | val_0_rmse: 0.5453  |  0:10:20s
# epoch 216| loss: 0.12541 | val_0_rmse: 0.54659 |  0:10:23s
# epoch 217| loss: 0.12666 | val_0_rmse: 0.54814 |  0:10:25s
# epoch 218| loss: 0.12587 | val_0_rmse: 0.55045 |  0:10:28s
# epoch 219| loss: 0.12614 | val_0_rmse: 0.54816 |  0:10:30s
# epoch 220| loss: 0.12642 | val_0_rmse: 0.546   |  0:10:33s
# epoch 221| loss: 0.12561 | val_0_rmse: 0.54461 |  0:10:36s
# epoch 222| loss: 0.12641 | val_0_rmse: 0.54746 |  0:10:38s
# epoch 223| loss: 0.12655 | val_0_rmse: 0.5482  |  0:10:41s
# epoch 224| loss: 0.12612 | val_0_rmse: 0.54427 |  0:10:43s
# epoch 225| loss: 0.12625 | val_0_rmse: 0.54448 |  0:10:46s
# epoch 226| loss: 0.12614 | val_0_rmse: 0.54492 |  0:10:48s
# epoch 227| loss: 0.12626 | val_0_rmse: 0.54674 |  0:10:51s
# epoch 228| loss: 0.12622 | val_0_rmse: 0.54622 |  0:10:53s
# epoch 229| loss: 0.12601 | val_0_rmse: 0.54365 |  0:10:55s
# epoch 230| loss: 0.12553 | val_0_rmse: 0.54688 |  0:10:58s
# epoch 231| loss: 0.12674 | val_0_rmse: 0.54534 |  0:11:00s
# epoch 232| loss: 0.12573 | val_0_rmse: 0.5434  |  0:11:03s
# epoch 233| loss: 0.12626 | val_0_rmse: 0.54883 |  0:11:05s
# epoch 234| loss: 0.12644 | val_0_rmse: 0.54684 |  0:11:08s
# epoch 235| loss: 0.12631 | val_0_rmse: 0.5477  |  0:11:10s
# epoch 236| loss: 0.12678 | val_0_rmse: 0.54905 |  0:11:13s
# epoch 237| loss: 0.12636 | val_0_rmse: 0.54663 |  0:11:15s
# epoch 238| loss: 0.1264  | val_0_rmse: 0.54574 |  0:11:18s
# epoch 239| loss: 0.12629 | val_0_rmse: 0.54404 |  0:11:20s
# epoch 240| loss: 0.12653 | val_0_rmse: 0.54517 |  0:11:23s
# epoch 241| loss: 0.12552 | val_0_rmse: 0.5468  |  0:11:25s
# epoch 242| loss: 0.12651 | val_0_rmse: 0.54459 |  0:11:28s
# epoch 243| loss: 0.12589 | val_0_rmse: 0.55245 |  0:11:30s
# epoch 244| loss: 0.126   | val_0_rmse: 0.54346 |  0:11:33s
# epoch 245| loss: 0.12615 | val_0_rmse: 0.55071 |  0:11:35s
# epoch 246| loss: 0.12582 | val_0_rmse: 0.54576 |  0:11:38s
# epoch 247| loss: 0.12628 | val_0_rmse: 0.54577 |  0:11:40s
# epoch 248| loss: 0.12629 | val_0_rmse: 0.5479  |  0:11:43s
# epoch 249| loss: 0.12532 | val_0_rmse: 0.54561 |  0:11:45s
# epoch 250| loss: 0.12597 | val_0_rmse: 0.5482  |  0:11:48s
# epoch 251| loss: 0.12584 | val_0_rmse: 0.54309 |  0:11:50s
# epoch 252| loss: 0.12623 | val_0_rmse: 0.5466  |  0:11:52s
# epoch 253| loss: 0.12552 | val_0_rmse: 0.54546 |  0:11:55s
# epoch 254| loss: 0.12586 | val_0_rmse: 0.54384 |  0:11:57s
# epoch 255| loss: 0.12602 | val_0_rmse: 0.54938 |  0:12:00s
# epoch 256| loss: 0.12624 | val_0_rmse: 0.54678 |  0:12:02s
# epoch 257| loss: 0.12584 | val_0_rmse: 0.54712 |  0:12:05s
# epoch 258| loss: 0.12649 | val_0_rmse: 0.54766 |  0:12:07s
# epoch 259| loss: 0.12566 | val_0_rmse: 0.54507 |  0:12:10s
# epoch 260| loss: 0.12654 | val_0_rmse: 0.5457  |  0:12:12s
# epoch 261| loss: 0.12568 | val_0_rmse: 0.54405 |  0:12:15s
# epoch 262| loss: 0.12622 | val_0_rmse: 0.54535 |  0:12:17s
# epoch 263| loss: 0.12562 | val_0_rmse: 0.54259 |  0:12:20s
# epoch 264| loss: 0.12642 | val_0_rmse: 0.54626 |  0:12:22s
# epoch 265| loss: 0.12561 | val_0_rmse: 0.54714 |  0:12:25s
#
# Early stopping occurred at epoch 265 with best_epoch = 65 and best_val_0_rmse = 0.54068
# Best weights from best epoch are automatically used!
# [INFO] Time 745.65

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ### Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = testX[:, -1] - testY[:, i]
    pred[:, i]  = testX[:, -1] - pred[:, i]

# %% [markdown]
# ### Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i] 
    Prices['Prediction'] = pred[:, i]   



    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]

#     # Present results
#     #
#     print('Horizon: ', i)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# [INFO] Feature:  NO2
# ------------------------------------------------
# Horizon:  1 MAE  6.90 SMAPE: 11.07 R2: 0.93
# Horizon:  2 MAE 11.96 SMAPE: 19.13 R2: 0.80
# Horizon:  3 MAE 15.43 SMAPE: 25.09 R2: 0.69
# Horizon:  4 MAE 18.40 SMAPE: 30.24 R2: 0.60

# %%
# NO2 - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  6.90 SMAPE: 11.07 R2: 0.93
# Horizon:  2 MAE 11.96 SMAPE: 19.13 R2: 0.80
# Horizon:  3 MAE 15.43 SMAPE: 25.09 R2: 0.69
# Horizon:  4 MAE 18.40 SMAPE: 30.24 R2: 0.60

# %% [markdown]
# ## Visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i] 
    Prices['Prediction'] = pred[:, i] 
            
            
    # Plot Real & Predicted values
    #
    Prices[:100].plot( figsize = (20, 3), marker = 'o' )
    #
    plt.title('Feature: {} - Horizon = {}'.format(targetSeries, i+1))
    plt.legend( frameon = False, fontsize = 14)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
# Out:
# [INFO] Feature:  NO2
# ------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame([])
#
#
Outputs[targetSeries]  = testY.flatten()
Outputs['TabNet_diff'] = pred.flatten()
#
#
Outputs.to_csv('Predictions/TabNet_diff.csv')
