# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  200
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.51 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'CO', 'NO2']] )
df = pd.DataFrame( df[['CO', 'NO2']] )
# df = pd.DataFrame( df[ 'NO2' ] )


df.head(3)
# Out:
#                              CO         NO2
# Date
# 2022-02-19 00:00:00  248.947368  186.210526
# 2022-02-19 00:05:00  232.473684  151.052632
# 2022-02-19 00:10:00  226.947368  135.315789

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()
#
# df['MA5'] = df[ targetSeries ].rolling(5).mean()
# df['MA9'] = df[ targetSeries ].rolling(9).mean()

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = StandardScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = StandardScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, includeLagData = False, includeDate = False, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY = [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Original data
        data       = df.to_numpy()[i+1:(i+Lag)]        
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist(), 
                       np.cos(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            # Concatenate data            
            data = np.concatenate([data, myDate], axis = -1)

        # data_diff: Lag-d differences
        if (includeLagData):
            data_diff  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy()
            #
            # Concatenate data
            data = np.concatenate([data, data_diff], axis = -1)
                
        
        # Concatenate data
        dataX.append( data )
        
        # Targets 
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df             = df_train, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = Horizon)
                               

testX,  testY  = create_dataset(df             = df_test, 
                                Lag            = Lag, 
                                Horizon        = Horizon, 
                                targetSeries   = targetSeries,
                                includeLagData = True,
                                includeDate    = False,
                                overlap        = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0] )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:03<00:00, 1330.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:02<00:00, 1432.78it/s]
# Training instances:     4276
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4276, 11, 4), (4276, 4))

# %% [markdown]
# # Forecasting model

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *

# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )

# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')( Decoder )
#
# Output
#
Outputs = Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)
# Out:
# 2022-05-11 15:01:35.261567: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/Hybrid.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 40)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 20)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/200
# 134/134 [==============================] - 6s 20ms/step - loss: 0.3488 - MAE: 0.4081 - RMSE: 0.5906 - val_loss: 0.9300 - val_MAE: 0.5823 - val_RMSE: 0.9644 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1363 - MAE: 0.2479 - RMSE: 0.3692 - val_loss: 0.3764 - val_MAE: 0.4011 - val_RMSE: 0.6135 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1301 - MAE: 0.2374 - RMSE: 0.3608 - val_loss: 0.3112 - val_MAE: 0.3620 - val_RMSE: 0.5578 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1284 - MAE: 0.2360 - RMSE: 0.3584 - val_loss: 0.3012 - val_MAE: 0.3474 - val_RMSE: 0.5488 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.1276 - MAE: 0.2340 - RMSE: 0.3572 - val_loss: 0.2914 - val_MAE: 0.3534 - val_RMSE: 0.5398 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1275 - MAE: 0.2337 - RMSE: 0.3571 - val_loss: 0.2889 - val_MAE: 0.3490 - val_RMSE: 0.5375 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1264 - MAE: 0.2327 - RMSE: 0.3555 - val_loss: 0.3398 - val_MAE: 0.3748 - val_RMSE: 0.5829 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1280 - MAE: 0.2363 - RMSE: 0.3578 - val_loss: 0.2844 - val_MAE: 0.3501 - val_RMSE: 0.5333 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1262 - MAE: 0.2333 - RMSE: 0.3552 - val_loss: 0.3575 - val_MAE: 0.3868 - val_RMSE: 0.5979 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1238 - MAE: 0.2307 - RMSE: 0.3519 - val_loss: 0.3137 - val_MAE: 0.3574 - val_RMSE: 0.5601 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1276 - MAE: 0.2341 - RMSE: 0.3572 - val_loss: 0.2920 - val_MAE: 0.3646 - val_RMSE: 0.5404 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.
200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1166 - MAE: 0.2230 - RMSE: 0.3414 - val_loss: 0.2965 - val_MAE: 0.3425 - val_RMSE: 0.5445 - lr: 5.0000e-04
# Epoch 34/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1166 - MAE: 0.2221 - RMSE: 0.3415 - val_loss: 0.2834 - val_MAE: 0.3474 - val_RMSE: 0.5324 - lr: 5.0000e-04
# Epoch 35/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1167 - MAE: 0.2241 - RMSE: 0.3416 - val_loss: 0.2845 - val_MAE: 0.3335 - val_RMSE: 0.5334 - lr: 5.0000e-04
# Epoch 36/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1158 - MAE: 0.2226 - RMSE: 0.3403 - val_loss: 0.2837 - val_MAE: 0.3471 - val_RMSE: 0.5327 - lr: 5.0000e-04
# Epoch 37/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1175 - MAE: 0.2244 - RMSE: 0.3428 - val_loss: 0.2837 - val_MAE: 0.3540 - val_RMSE: 0.5326 - lr: 5.0000e-04
# Epoch 38/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1163 - MAE: 0.2229 - RMSE: 0.3410 - val_loss: 0.2999 - val_MAE: 0.3938 - val_RMSE: 0.5476 - lr: 5.0000e-04
# Epoch 39/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1162 - MAE: 0.2231 - RMSE: 0.3409 - val_loss: 0.2980 - val_MAE: 0.3752 - val_RMSE: 0.5459 - lr: 5.0000e-04
# Epoch 40/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1160 - MAE: 0.2231 - RMSE: 0.3406 - val_loss: 0.3370 - val_MAE: 0.3672 - val_RMSE: 0.5805 - lr: 5.0000e-04
# Epoch 41/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1128 - MAE: 0.2172 - RMSE: 0.3358 - val_loss: 0.2958 - val_MAE: 0.3804 - val_RMSE: 0.5439 - lr: 2.5000e-04
# Epoch 42/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1130 - MAE: 0.2185 - RMSE: 0.3362 - val_loss: 0.2871 - val_MAE: 0.3467 - val_RMSE: 0.5358 - lr: 2.5000e-04
# Epoch 43/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1125 - MAE: 0.2181 - RMSE: 0.3354 - val_loss: 0.2907 - val_MAE: 0.3394 - val_RMSE: 0.5392 - lr: 2.5000e-04
# Epoch 44/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1120 - MAE: 0.2175 - RMSE: 0.3346 - val_loss: 0.2879 - val_MAE: 0.3607 - val_RMSE: 0.5366 - lr: 2.5000e-04
# Epoch 45/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1127 - MAE: 0.2186 - RMSE: 0.3357 - val_loss: 0.2910 - val_MAE: 0.3439 - val_RMSE: 0.5395 - lr: 2.5000e-04
# Epoch 46/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1118 - MAE: 0.2170 - RMSE: 0.3344 - val_loss: 0.2895 - val_MAE: 0.3393 - val_RMSE: 0.5381 - lr: 2.5000e-04
# Epoch 47/200
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1115 - MAE: 0.2157 - RMSE: 0.3340 - val_loss: 0.2932 - val_MAE: 0.3410 - val_RMSE: 0.5415 - lr: 2.5000e-04
# Epoch 48/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1116 - MAE: 0.2165 - RMSE: 0.3340 - val_loss: 0.2908 - val_MAE: 0.3658 - val_RMSE: 0.5392 - lr: 2.5000e-04
# Epoch 49/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1108 - MAE: 0.2170 - RMSE: 0.3329 - val_loss: 0.2929 - val_MAE: 0.3432 - val_RMSE: 0.5412 - lr: 2.5000e-04
# Epoch 50/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1114 - MAE: 0.2171 - RMSE: 0.3337 - val_loss: 0.2898 - val_MAE: 0.3461 - val_RMSE: 0.5383 - lr: 2.5000e-04
# Epoch 51/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1108 - MAE: 0.2158 - RMSE: 0.3328 - val_loss: 0.2894 - val_MAE: 0.3556 - val_RMSE: 0.5379 - lr: 2.5000e-04
# Epoch 52/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1101 - MAE: 0.2157 - RMSE: 0.3318 - val_loss: 0.2952 - val_MAE: 0.3497 - val_RMSE: 0.5434 - lr: 2.5000e-04
# Epoch 53/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1104 - MAE: 0.2163 - RMSE: 0.3323 - val_loss: 0.2920 - val_MAE: 0.3699 - val_RMSE: 0.5404 - lr: 2.5000e-04
# Epoch 54/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1103 - MAE: 0.2164 - RMSE: 0.3321 - val_loss: 0.3011 - val_MAE: 0.3386 - val_RMSE: 0.5487 - lr: 2.5000e-04
# Epoch 55/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.1097 - MAE: 0.2148 - RMSE: 0.3313 - val_loss: 0.2964 - val_MAE: 0.3696 - val_RMSE: 0.5445 - lr: 2.5000e-04
# Epoch 56/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1107 - MAE: 0.2164 - RMSE: 0.3327 - val_loss: 0.2870 - val_MAE: 0.3525 - val_RMSE: 0.5357 - lr: 2.5000e-04
# Epoch 57/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1107 - MAE: 0.2166 - RMSE: 0.3326 - val_loss: 0.2941 - val_MAE: 0.3473 - val_RMSE: 0.5423 - lr: 2.5000e-04
# Epoch 58/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1099 - MAE: 0.2163 - RMSE: 0.3316 - val_loss: 0.2958 - val_MAE: 0.3711 - val_RMSE: 0.5439 - lr: 2.5000e-04
# Epoch 59/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1100 - MAE: 0.2167 - RMSE: 0.3316 - val_loss: 0.2903 - val_MAE: 0.3622 - val_RMSE: 0.5388 - lr: 2.5000e-04
# Epoch 60/200
# 134/134 [==============================] - 2s 14ms/step - loss: 0.1096 - MAE: 0.2163 - RMSE: 0.3310 - val_loss: 0.2955 - val_MAE: 0.3406 - val_RMSE: 0.5436 - lr: 2.5000e-04
# Epoch 00060: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/Hybrid.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred = np.exp( pred )   - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue',   marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  6.89 SMAPE: 11.34 R2: 0.93
# Horizon:  2 MAE 11.67 SMAPE: 19.01 R2: 0.81
# Horizon:  3 MAE 14.92 SMAPE: 24.61 R2: 0.72
# Horizon:  4 MAE 17.56 SMAPE: 29.49 R2: 0.63

# %%
# NO2 + CO (d-Lag+Value) - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  6.89 SMAPE: 11.34 R2: 0.93
# Horizon:  2 MAE 11.67 SMAPE: 19.01 R2: 0.81
# Horizon:  3 MAE 14.92 SMAPE: 24.61 R2: 0.72
# Horizon:  4 MAE 17.56 SMAPE: 29.49 R2: 0.63

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )  
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Hybrid']       = pred.flatten()

Outputs.to_csv('Predictions/Hybrid.csv')
