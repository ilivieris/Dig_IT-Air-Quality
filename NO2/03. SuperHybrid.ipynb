# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# import tensorflow as tf
# tf.config.experimental_run_functions_eagerly(True)
# tf.keras.backend.set_floatx('float64')

# import tensorflow.python.util.deprecation as deprecation
# deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import math
import time
import timeit
from   tqdm    import tqdm
import pandas  as pd
import numpy   as np


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot                        as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from utils.PerformanceMetrics import RegressionEvaluation


print('[INFO] Libraries imported')
# Out:
# [INFO] Libraries imported

# %% [markdown]
# # Parameters

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Training paramers

# %%
Lag        =   16
Horizon    =    4
#
epochs     =  100
batch_size =   32

Transformation = True

# %% [markdown]
# # Importing data

# %%
# Parameters
#
filename   = '../metadata/7-kanal-1.csv'

Transformation  = True
Scaling         = 'Standard'

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.55 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'CO', 'NO2']] )
df = pd.DataFrame( df[['CO', 'NO2']] )
# df = pd.DataFrame( df[ 'NO2' ] )


df.head(3)
# Out:
#                              CO         NO2
# Date
# 2022-02-19 00:00:00  248.947368  186.210526
# 2022-02-19 00:05:00  232.473684  151.052632
# 2022-02-19 00:10:00  226.947368  135.315789

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ## Include MA-based features

# %%
# df['MA6']  = df[ targetSeries ].rolling(6).mean()
# df['MA12'] = df[ targetSeries ].rolling(12).mean()
#
# df['MA5'] = df[ targetSeries ].rolling(5).mean()
# df['MA9'] = df[ targetSeries ].rolling(9).mean()

# %% [markdown]
# ## Split Training/Testing set

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
print('Training: ', df_train.shape[0])
print('Testing:  ', df_test.shape[0])
# Out:
# Training:  17116
# Testing:   4280

# %% [markdown]
# ## Visualize Training & Testing data

# %%
plt.figure( figsize = (20, 4) );
#
df_train[ targetSeries ].plot()
df_test[ targetSeries ].plot()
#
plt.legend(['Training', 'Validation', 'Testing'], fontsize = 12);
plt.ylabel( targetSeries, size = 12);
plt.xlabel( 'Time', size = 12);

# %% [markdown]
# ## Fix lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Contruction of fitting data for training a forecasting model

# %% [markdown]
# ### Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(-df.min().min(), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ### Data scaling

# %%
for feature in df_train.columns:
    if (feature == targetSeries): continue

    # Setup scaler
    #
    scaler = RobustScaler()

    # Performing Scaling - for each feature
    df_train[feature] = scaler.fit_transform( df_train[feature].to_numpy().reshape(-1,1) )
    df_test[feature]  = scaler.transform( df_test[feature].to_numpy().reshape(-1,1) )


# Setup scaler
#
scaler = RobustScaler()

df_train[targetSeries] = scaler.fit_transform( df_train[targetSeries].to_numpy().reshape(-1,1) )
df_test[targetSeries]  = scaler.transform( df_test[targetSeries].to_numpy().reshape(-1,1) )

# %% [markdown]
# ### Create fitting data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, includeLagData = False, includeDate = False, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY, CurrentValue = [], [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        # Original data
        data       = df.to_numpy()[i+1:(i+Lag)]        
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist(), 
                       np.cos(df[i+1:(i+Lag)].index.hour + df[i+1:(i+Lag)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            # Concatenate data            
            data = np.concatenate([data, myDate], axis = -1)

        # data_diff: Lag-d differences
        if (includeLagData):
            data_diff  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy()
            #
            # Concatenate data
            data = np.concatenate([data, data_diff], axis = -1)
                
        
        # Concatenate data
        dataX.append( data )
        
        
        # Current value
        CurrentValue.append( df[ targetSeries ].to_numpy()[i+Lag-1] )
        
        
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )        
        
    return ( np.array(dataX), np.array(dataY), np.array(CurrentValue) )

# %%
trainX, trainY, _ = create_dataset(df            = df_train, 
                                  Lag            = Lag, 
                                  Horizon        = Horizon, 
                                  targetSeries   = targetSeries,
                                  includeLagData = True,
                                  includeDate    = False,
                                  overlap        = Horizon)
                               

testX,  testY, test_CurrentValue = create_dataset(df             = df_test, 
                                                 Lag            = Lag, 
                                                 Horizon        = Horizon, 
                                                 targetSeries   = targetSeries,
                                                 includeLagData = True,
                                                 includeDate    = False,
                                                 overlap        = 1)


print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0] )
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4275/4275 [00:04<00:00, 869.37it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4277/4277 [00:04<00:00, 877.66it/s]
# Training instances:     4275
# Testing instances:      4277

# %%
trainX.shape, trainY.shape
# Out:
# ((4275, 15, 4), (4275, 4))

# %% [markdown]
# # Forecasting model

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.models                  import *

# Inputs
#
Inputs = Input(shape = (trainX.shape[1], trainX.shape[2]))


# Encoder
#
Encoder = LSTM(units = 100, activation='relu')( Inputs )

# Decoder
#
Decoder = RepeatVector( Horizon )(Encoder)
#
Decoder = LSTM(units = 100, activation='relu')( Decoder )
#
# Output
#
Outputs = Dense( Horizon, activation='linear' )( Decoder )


# Create model
#
model = Model(inputs = Inputs, outputs = Outputs)
# Out:
# 2022-05-11 15:01:48.874061: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training forecasting model

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/SuperHybrid.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 40)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 20)

# %%
# Start clock
#
start = timeit.default_timer()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = timeit.default_timer()
# Out:
# Epoch 1/100
# 134/134 [==============================] - 6s 23ms/step - loss: 0.0778 - MAE: 0.1790 - RMSE: 0.2790 - val_loss: 0.1751 - val_MAE: 0.2630 - val_RMSE: 0.4184 - lr: 5.0000e-04
# Epoch 2/100
# 134/134 [==============================] - 3s 19ms/step - loss: 0.0756 - MAE: 0.1767 - RMSE: 0.2750 - val_loss: 0.1720 - val_MAE: 0.2550 - val_RMSE: 0.4147 - lr: 5.0000e-04
# Epoch 3/100
# 134/134 [==============================] - 3s 19ms/step - loss: 0.0751 - MAE: 0.1759 - RMSE: 0.2741 - val_loss: 0.1741 - val_MAE: 0.2708 - val_RMSE: 0.4172 - lr: 5.0000e-04
# Epoch 4/100
# 134/134 [==============================] - 3s 19ms/step - loss: 0.0747 - MAE: 0.1768 - RMSE: 0.2734 - val_loss: 0.1694 - val_MAE: 0.2665 - val_RMSE: 0.4116 - lr: 5.0000e-04
# Epoch 5/100
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0743 - MAE: 0.1753 - RMSE: 0.2725 - val_loss: 0.1728 - val_MAE: 0.2721 - val_RMSE: 0.4157 - lr: 5.0000e-04
# Epoch 6/100
# 134/134 [==============================] - 2s 18ms/step - loss: 0.0736 - MAE: 0.1755 - RMSE: 0.2713 - val_loss: 0.1686 - val_MAE: 0.2617 - val_RMSE: 0.4106 - lr: 5.0000e-04
# Epoch 7/100
# 134/134 [==============================] - 2s 18ms/step - loss: 0.0735 - MAE: 0.1753 - RMSE: 0.2710 - val_loss: 0.1693 - val_MAE: 0.2709 - val_RMSE: 0.4115 - lr: 5.0000e-04
# Epoch 8/100
# 134/134 [==============================] - 2s 19ms/step - loss: 0.0731 - MAE: 0.1745 - RMSE: 0.2704 - val_loss: 0.1691 - val_MAE: 0.2616 - val_RMSE: 0.4112 - lr: 5.0000e-04
# Epoch 9/100
# 134/134 [==============================] - 2s 18ms/step - loss: 0.
# Epoch 43/100
# 134/134 [==============================] - 2s 18ms/step - loss: 0.0621 - MAE: 0.1628 - RMSE: 0.2492 - val_loss: 0.1820 - val_MAE: 0.2758 - val_RMSE: 0.4266 - lr: 2.5000e-04
# Epoch 44/100
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0616 - MAE: 0.1624 - RMSE: 0.2482 - val_loss: 0.1747 - val_MAE: 0.2652 - val_RMSE: 0.4180 - lr: 2.5000e-04
# Epoch 45/100
# 134/134 [==============================] - 2s 15ms/step - loss: 0.0617 - MAE: 0.1617 - RMSE: 0.2483 - val_loss: 0.1721 - val_MAE: 0.2621 - val_RMSE: 0.4149 - lr: 2.5000e-04
# Epoch 46/100
# 134/134 [==============================] - 2s 14ms/step - loss: 0.0613 - MAE: 0.1613 - RMSE: 0.2475 - val_loss: 0.1803 - val_MAE: 0.2749 - val_RMSE: 0.4246 - lr: 2.5000e-04
# Epoch 47/100
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0610 - MAE: 0.1615 - RMSE: 0.2470 - val_loss: 0.1789 - val_MAE: 0.2748 - val_RMSE: 0.4230 - lr: 2.5000e-04
# Epoch 48/100
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0606 - MAE: 0.1604 - RMSE: 0.2462 - val_loss: 0.1842 - val_MAE: 0.2752 - val_RMSE: 0.4292 - lr: 2.5000e-04
# Epoch 49/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0603 - MAE: 0.1607 - RMSE: 0.2455 - val_loss: 0.1790 - val_MAE: 0.2697 - val_RMSE: 0.4231 - lr: 2.5000e-04
# Epoch 50/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0603 - MAE: 0.1607 - RMSE: 0.2456 - val_loss: 0.1764 - val_MAE: 0.2661 - val_RMSE: 0.4200 - lr: 2.5000e-04
# Epoch 51/100
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0604 - MAE: 0.1603 - RMSE: 0.2458 - val_loss: 0.1755 - val_MAE: 0.2633 - val_RMSE: 0.4190 - lr: 2.5000e-04
# Epoch 00051: early stopping

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized forecasting model

# %%
# Load the best model
#
model.load_weights('models/SuperHybrid.hdf5')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

# %% [markdown]
# ## Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = test_CurrentValue - testY[:, i]
    pred[:, i]  = test_CurrentValue - pred[:, i]

# %% [markdown]
# ## Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ## Visualization of predictions

# %%
Results = dict()

for i in range( Horizon ):
    Prices = pd.DataFrame( [] )

    Prices[targetSeries] = testY[:,i]
    Prices['Prediction'] = pred[:,i]
    

        
    # Store results
    #
    Results[ 'Horizon {}'.format(i+1) ] = Prices

    
    
    
    # Plot results
    #
    plt.figure( figsize = (20, 4) );
    #
    Prices[ targetSeries ][:100].plot(color = 'tab:blue',   marker = 'o')
    Prices[ 'Prediction' ][:100].plot(color = 'tab:orange', marker = 'o')
    
    #
    #
    plt.legend([targetSeries, 'Prediction'], fontsize = 12, frameon=False);
    plt.ylabel(targetSeries, size = 12 );
    plt.xlabel('Time', size = 12);
    plt.show()

# %% [markdown]
# ## Regression evaluation

# %%
sResults = {'MAE': [], 'RMSE': [], 'MAPE': [], 'SMAPE': [], 'R2': []}

for i in range(Horizon):
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Results['Horizon {}'.format(i+1)] )
    
    sResults['MAE']   += [MAE]
    sResults['RMSE']  += [RMSE]
    sResults['MAPE']  += [MAPE]
    sResults['SMAPE'] += [SMAPE]
    sResults['R2']    += [R2]
    
    
#     print('Horizon -%i-' % (i+1))
#     print('--------------')
#     print('MAE   = %.3f' % MAE)
#     print('RMSE  = %.3f' % RMSE)
#     print('MAPE  = %.3f' % MAPE)
#     print('SMAPE = %.3f' % SMAPE)
#     print('R2    = %.3f' % R2)
#     print()
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' %(i+1, MAE, SMAPE, R2) )
# Out:
# Horizon:  1 MAE  7.09 SMAPE: 11.23 R2: 0.93
# Horizon:  2 MAE 12.12 SMAPE: 19.48 R2: 0.81
# Horizon:  3 MAE 15.31 SMAPE: 25.11 R2: 0.71
# Horizon:  4 MAE 18.07 SMAPE: 30.40 R2: 0.63

# %%
# NO2 + CO (d-Lag+Value) - Log+RobustScaler
# ------------------------------------------------
Horizon:  1 MAE  7.09 SMAPE: 11.23 R2: 0.93
Horizon:  2 MAE 12.12 SMAPE: 19.48 R2: 0.81
Horizon:  3 MAE 15.31 SMAPE: 25.11 R2: 0.71
Horizon:  4 MAE 18.07 SMAPE: 30.40 R2: 0.63

# %%
# print('[INFO] Feature: ', targetSeries)
# print('------------------------------------------------')
# Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

# for i in range( Horizon ):

#     Prices[targetSeries] = testY[:,i]
#     Prices['Prediction'] = pred[:,i]
    
            
#     from scipy import stats
#     from statsmodels.graphics.tsaplots import plot_acf
    
#     res = (Prices[targetSeries] - Prices['Prediction']).to_numpy()
    
#     fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

#     ax[0].hist( res, bins = 100 )    
#     plot_acf( res, ax=ax[1] )

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )  
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
plt.show()

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['Hybrid']       = pred.flatten()

Outputs.to_csv('Predictions/SuperHybrid.csv')
