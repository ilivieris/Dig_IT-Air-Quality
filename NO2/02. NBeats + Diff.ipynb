# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
import tensorflow 
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.callbacks               import EarlyStopping
from   tensorflow.keras.callbacks               import ModelCheckpoint
from   tensorflow.keras.callbacks               import ReduceLROnPlateau


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.plot_scatter       import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## CUDA

# %%
try:
    gpus = tensorflow.config.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tensorflow.config.experimental.set_memory_growth(gpu, True)

            logical_gpus = tensorflow.config.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")

        except RuntimeError as e:

            # Memory growth must be set before GPUs have been initialized
            print(e)
except:
    print('[INFO] Not GPU found')

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename        = '../metadata/7-kanal-1.csv'
#
Transformation  = True
Scaling         = 'Robust'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        =   12
Horizon    =    4
#
epochs     =  200
batch_size =   32

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 0.30 seconds
#                   Date  Temperature  Humidity  PM2.5  PM10    NO2     CO
# 0  2022-02-19 00:00:09         -2.4      86.0    2.7   4.9  212.0  263.0
# 1  2022-02-19 00:00:25         -2.4      86.0    2.7   7.6  209.0  261.0
# 2  2022-02-19 00:00:41         -2.4      86.0    2.6   7.3  204.0  258.0

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)


df = df.resample('5min').mean().interpolate()
# df = pd.DataFrame( df[['Temperature', 'Humidity', 'CO', 'NO2']] )
df = pd.DataFrame( df[['CO', 'NO2']] )
# df = pd.DataFrame( df[ 'NO2' ] )


df.head(3)
# Out:
#                              CO         NO2
# Date
# 2022-02-19 00:00:00  248.947368  186.210526
# 2022-02-19 00:05:00  232.473684  151.052632
# 2022-02-19 00:10:00  226.947368  135.315789

# %%
targetSeries = df.columns[-1]

# %% [markdown]
# ### Split training/testing datasets

# %%
idx = int( df.shape[0] * 0.8 )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train[ targetSeries ].plot(ax=ax, color='tab:blue' )
df_test[ targetSeries ].plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = max(df.min().min(), 1.0)
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = MinMaxScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = MinMaxScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
            
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = RobustScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = RobustScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
        
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
           
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    for feature in df.columns:
        if (feature == targetSeries): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df_train[targetSeries] = scaler.fit_transform( df_train[ targetSeries ].to_numpy().reshape(-1,1) )
    df_test[targetSeries]  = scaler.transform( df_test[ targetSeries ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Robust
# Feature:  CO

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, targetSeries = None, overlap = 1, includeDate = False):
    
    if (targetSeries is None):
        print('[INFO] Target series is not defined')
        return (None, None, None)
    
    dataX, CurrentValue, dataY = [], [], []
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):

        # Instances: Lag-d differences
        Instance  = (df.iloc[i+Lag-1] - df.iloc[i:(i+Lag-1)]).to_numpy().tolist() 
        
        # Include date info
        if (includeDate):            
            myDate = [ np.sin(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist(), 
                       np.cos(df[i:(i+Lag-1)].index.hour + df[i:(i+Lag-1)].index.minute / 60 ).tolist() ]
            myDate = np.asarray( myDate ).T
            #
            Instance = np.concatenate([Instance, myDate], axis = -1)

        # Current value
        CurrentValue.append( df[ targetSeries ].to_numpy()[i+Lag-1] )
        # Append instance
        dataX.append( Instance ) 
                
        # Target Instance
        Instance = (df[ targetSeries ][i+Lag-1] - df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon])
        # Append instance
        dataY.append( Instance )

        
    return ( np.array(dataX), np.array(dataY), np.array(CurrentValue) )

# %%
trainX, trainY, _                = create_dataset(df           = df_train, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,
                                                  overlap      = Horizon,)

testX,  testY, test_CurrentValue = create_dataset(df           = df_test, 
                                                  Lag          = Lag, 
                                                  Horizon      = Horizon, 
                                                  targetSeries = targetSeries,
                                                  includeDate  = False,                                                
                                                  overlap      = 4)


# trainX = np.expand_dims(trainX, axis=-1)
# testX  = np.expand_dims(testX, axis=-1)
print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4276/4276 [00:01<00:00, 2616.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1070/1070 [00:00<00:00, 2601.89it/s]
# Training instances:     4276
# Testing instances:      1070

# %%
trainX.shape, testY.shape
# Out:
# ((4276, 11, 2), (1070, 4))

# %% [markdown]
# # Forecasting model: NBeats

# %%
import random, os
seed = 42
    
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
tensorflow.random.set_seed(seed)

# %% [markdown]
# ## Setup model

# %%
from utils.NBeats_Keras import NBeatsNet


model = NBeatsNet(stack_types            = (NBeatsNet.GENERIC_BLOCK, NBeatsNet.GENERIC_BLOCK),
                  input_dim              = trainX.shape[2],
                  forecast_length        = Horizon, 
                  backcast_length        = trainX.shape[1], # Lag-1
                  hidden_layer_units     = 256,
                  nb_blocks_per_stack    = 4,
                  share_weights_in_stack = False,
                  activation_function    = 'relu')
# Out:
# 2022-05-13 10:24:52.946893: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Training parameters

# %%
# Define metrics
#
metrics = [
            MeanAbsoluteError(name = "MAE", dtype = None),
            RootMeanSquaredError(name = 'RMSE', dtype = None),
          ]


model.compile(loss      = 'mse', 
              optimizer = Adam(learning_rate = 5.e-4), 
              metrics   = metrics)

# %%
# Checkpoint
#
checkpoint = ModelCheckpoint("models/NBeats_Diff.hdf5", 
                              monitor        = 'val_loss', 
                              verbose        = 0, 
                              save_best_only = True, 
                              mode           = 'min')

# Earlystopping
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              mode          = 'min', 
                              verbose       = 1, 
                              patience      = 20)

# Learning rate adjustment
#
lrs_scheduler  = ReduceLROnPlateau(monitor     = 'val_loss', 
                                   factor      = 0.5,
                                   patience    = 10)

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs          = epochs, 
                  batch_size      = batch_size, 
                  callbacks       = [checkpoint, earlystopping, lrs_scheduler],
                  verbose         = True, 
                  shuffle         = True,
                  validation_data = (testX, testY))


# Terminate clock
#
stop = time.time()
print('[INFO] Time %.2f' % (stop - start))
# Out:
# Epoch 1/200
# 134/134 [==============================] - 6s 18ms/step - loss: 0.0787 - MAE: 0.1772 - RMSE: 0.2805 - val_loss: 0.1633 - val_MAE: 0.2467 - val_RMSE: 0.4042 - lr: 5.0000e-04
# Epoch 2/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0777 - MAE: 0.1763 - RMSE: 0.2788 - val_loss: 0.1628 - val_MAE: 0.2441 - val_RMSE: 0.4035 - lr: 5.0000e-04
# Epoch 3/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0776 - MAE: 0.1757 - RMSE: 0.2786 - val_loss: 0.1620 - val_MAE: 0.2436 - val_RMSE: 0.4025 - lr: 5.0000e-04
# Epoch 4/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0768 - MAE: 0.1752 - RMSE: 0.2771 - val_loss: 0.1647 - val_MAE: 0.2460 - val_RMSE: 0.4058 - lr: 5.0000e-04
# Epoch 5/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.0765 - MAE: 0.1747 - RMSE: 0.2766 - val_loss: 0.1702 - val_MAE: 0.2521 - val_RMSE: 0.4126 - lr: 5.0000e-04
# Epoch 6/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0764 - MAE: 0.1748 - RMSE: 0.2764 - val_loss: 0.1643 - val_MAE: 0.2439 - val_RMSE: 0.4054 - lr: 5.0000e-04
# Epoch 7/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0762 - MAE: 0.1739 - RMSE: 0.2760 - val_loss: 0.1597 - val_MAE: 0.2420 - val_RMSE: 0.3996 - lr: 5.0000e-04
# Epoch 8/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0759 - MAE: 0.1735 - RMSE: 0.2754 - val_loss: 0.1616 - val_MAE: 0.2454 - val_RMSE: 0.4020 - lr: 5.0000e-04
# Epoch 9/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0761 - MAE: 0.1742 - RMSE: 0.2759 - val_loss: 0.1613 - val_MAE: 0.2418 - val_RMSE: 0.4017 - lr: 5.0000e-04
# Epoch 10/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0761 - MAE: 0.1743 - RMSE: 0.2759 - val_loss: 0.1612 - val_MAE: 0.2452 - val_RMSE: 0.4015 - lr: 5.0000e-04
# Epoch 11/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0760 - MAE: 0.1744 - RMSE: 0.2758 - val_loss: 0.1630 - val_MAE: 0.2426 - val_RMSE: 0.4037 - lr: 5.0000e-04
# Epoch 12/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0761 - MAE: 0.1739 - RMSE: 0.2758 - val_loss: 0.1589 - val_MAE: 0.2407 - val_RMSE: 0.3986 - lr: 5.0000e-04
# Epoch 13/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0758 - MAE: 0.1736 - RMSE: 0.2754 - val_loss: 0.1598 - val_MAE: 0.2420 - val_RMSE: 0.3997 - lr: 5.0000e-04
# Epoch 14/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0759 - MAE: 0.1743 - RMSE: 0.2756 - val_loss: 0.1618 - val_MAE: 0.2420 - val_RMSE: 0.4023 - lr: 5.0000e-04
# Epoch 15/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0754 - MAE: 0.1735 - RMSE: 0.2745 - val_loss: 0.1631 - val_MAE: 0.2428 - val_RMSE: 0.4038 - lr: 5.0000e-04
# Epoch 16/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0755 - MAE: 0.1734 - RMSE: 0.2748 - val_loss: 0.1574 - val_MAE: 0.2433 - val_RMSE: 0.3967 - lr: 5.0000e-04
# Epoch 17/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0752 - MAE: 0.1739 - RMSE: 0.2743 - val_loss: 0.1613 - val_MAE: 0.2443 - val_RMSE: 0.4016 - lr: 5.0000e-04
# Epoch 18/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0753 - MAE: 0.1733 - RMSE: 0.2744 - val_loss: 0.1598 - val_MAE: 0.2420 - val_RMSE: 0.3997 - lr: 5.0000e-04
# Epoch 19/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0752 - MAE: 0.1734 - RMSE: 0.2741 - val_loss: 0.1601 - val_MAE: 0.2410 - val_RMSE: 0.4001 - lr: 5.0000e-04
# Epoch 20/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0754 - MAE: 0.1739 - RMSE: 0.2745 - val_loss: 0.1587 - val_MAE: 0.2411 - val_RMSE: 0.3984 - lr: 5.0000e-04
# Epoch 21/200
# 134/134 [==============================] - 2s 13ms/step - loss: 0.0750 - MAE: 0.1734 - RMSE: 0.2739 - val_loss: 0.1609 - val_MAE: 0.2418 - val_RMSE: 0.4011 - lr: 5.0000e-04
# Epoch 22/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0750 - MAE: 0.1737 - RMSE: 0.2739 - val_loss: 0.1597 - val_MAE: 0.2427 - val_RMSE: 0.3997 - lr: 5.0000e-04
# Epoch 23/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0750 - MAE: 0.1733 - RMSE: 0.2738 - val_loss: 0.1614 - val_MAE: 0.2431 - val_RMSE: 0.4017 - lr: 5.0000e-04
# Epoch 24/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0749 - MAE: 0.1735 - RMSE: 0.2737 - val_loss: 0.1595 - val_MAE: 0.2419 - val_RMSE: 0.3994 - lr: 5.0000e-04
# Epoch 25/200
# 134/134 [==============================] - 2s 15ms/step - loss: 0.0748 - MAE: 0.1732 - RMSE: 0.2735 - val_loss: 0.1602 - val_MAE: 0.2421 - val_RMSE: 0.4002 - lr: 5.0000e-04
# Epoch 26/200
# 134/134 [==============================] - 2s 11ms/step - loss: 0.0745 - MAE: 0.1730 - RMSE: 0.2729 - val_loss: 0.1606 - val_MAE: 0.2436 - val_RMSE: 0.4008 - lr: 5.0000e-04
# Epoch 27/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0742 - MAE: 0.1726 - RMSE: 0.2724 - val_loss: 0.1602 - val_MAE: 0.2411 - val_RMSE: 0.4003 - lr: 2.5000e-04
# Epoch 28/200
# 134/134 [==============================] - 2s 12ms/step - loss: 0.0740 - MAE: 0.1723 - RMSE: 0.2720 - val_loss: 0.1600 - val_MAE: 0.2435 - val_RMSE: 0.4000 - lr: 2.5000e-04
# Epoch 29/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0739 - MAE: 0.1724 - RMSE: 0.2719 - val_loss: 0.1611 - val_MAE: 0.2452 - val_RMSE: 0.4014 - lr: 2.5000e-04
# Epoch 30/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.0737 - MAE: 0.1722 - RMSE: 0.2715 - val_loss: 0.1611 - val_MAE: 0.2436 - val_RMSE: 0.4013 - lr: 2.5000e-04
# Epoch 31/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.0739 - MAE: 0.1729 - RMSE: 0.2719 - val_loss: 0.1627 - val_MAE: 0.2445 - val_RMSE: 0.4033 - lr: 2.5000e-04
# Epoch 32/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0737 - MAE: 0.1721 - RMSE: 0.2714 - val_loss: 0.1608 - val_MAE: 0.2429 - val_RMSE: 0.4011 - lr: 2.5000e-04
# Epoch 33/200
# 134/134 [==============================] - 1s 10ms/step - loss: 0.0736 - MAE: 0.1723 - RMSE: 0.2713 - val_loss: 0.1605 - val_MAE: 0.2427 - val_RMSE: 0.4006 - lr: 2.5000e-04
# Epoch 34/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0737 - MAE: 0.1719 - RMSE: 0.2714 - val_loss: 0.1591 - val_MAE: 0.2420 - val_RMSE: 0.3988 - lr: 2.5000e-04
# Epoch 35/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0736 - MAE: 0.1725 - RMSE: 0.2712 - val_loss: 0.1615 - val_MAE: 0.2421 - val_RMSE: 0.4019 - lr: 2.5000e-04
# Epoch 36/200
# 134/134 [==============================] - 1s 11ms/step - loss: 0.0736 - MAE: 0.1716 - RMSE: 0.2713 - val_loss: 0.1603 - val_MAE: 0.2429 - val_RMSE: 0.4004 - lr: 2.5000e-04
# Epoch 00036: early stopping
# [INFO] Time 60.14

# %%
# Create figure
#
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 3) )

# Plot RMSE
#
ax[0].plot( score.history['RMSE'], marker = 'o');
ax[0].plot( score.history['val_RMSE'], marker = 'o');
ax[0].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[0].set_title('RMSE');

# Plot RMSE
#
ax[1].plot( score.history['MAE'], marker = 'o');
ax[1].plot( score.history['val_MAE'], marker = 'o');
ax[1].legend(['Training', 'Validation'], frameon = False, fontsize = 14);
ax[1].set_title('MAE');

# %% [markdown]
# ## Load optimized model

# %%
# Load the best model
#
model.load_weights('models/NBeats_Diff.hdf5')

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
# Get predictions
#
pred = model.predict( testX )

pred = pred.squeeze(-1)

# %% [markdown]
# ### Inverse "Lag-d Diff" transformation

# %%
for i in range( Horizon ):
    testY[:, i] = test_CurrentValue - testY[:, i]
    pred[:, i]  = test_CurrentValue - pred[:, i]

# %% [markdown]
# ### Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 



    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE  ]
    Performance_Foresting_Model['MAE']     += [ MAE   ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE ]
    Performance_Foresting_Model['R2']      += [ R2    ]

#     # Present results
#     #
#     print('Horizon: ', i+1)
#     print('> MAE:   ', MAE)
#     print('> RMSE:  ', RMSE)
#     print('> SMAPE: ', SMAPE)
#     print('> R2:    ', R2)
#     print()
    
    print('Horizon: %2i MAE %5.2f SMAPE: %5.2f R2: %.2f' % (i+1, MAE, SMAPE, R2) )
# Out:
# [INFO] Feature:  NO2
# ------------------------------------------------
# Horizon:  1 MAE  6.82 SMAPE: 10.95 R2: 0.94
# Horizon:  2 MAE 12.04 SMAPE: 18.71 R2: 0.80
# Horizon:  3 MAE 15.78 SMAPE: 24.59 R2: 0.68
# Horizon:  4 MAE 18.45 SMAPE: 29.10 R2: 0.58

# %%
# CO + NO2 - Log+StandardScaler
# ------------------------------------------------
# Horizon:  1 MAE  6.87 SMAPE: 10.85 R2: 0.93
# Horizon:  2 MAE 12.02 SMAPE: 18.64 R2: 0.80
# Horizon:  3 MAE 15.36 SMAPE: 23.88 R2: 0.69
# Horizon:  4 MAE 18.06 SMAPE: 28.33 R2: 0.60

# %% [markdown]
# ## Visualization

# %%
print('[INFO] Feature: ', targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 
            
    
    # Plot Real & Predicted values
    #
    Prices[:100].plot( figsize = (20, 3), marker = 'o' )
    #
    plt.title('Feature: {} - Horizon = {}'.format(targetSeries, i+1))
    plt.legend( frameon = False, fontsize = 14)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.show()
# Out:
# [INFO] Feature:  NO2
# ------------------------------------------------

# %% [markdown]
# ## Residual analysis

# %%
print('[INFO] Feature: ', targetSeries)
print(50 * '-')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

for i in range( Horizon ):

    Prices = pd.DataFrame([])        

    Prices['Real']       = testY[:,  i]
    Prices['Prediction'] = pred[:, i] 


            
    from scipy import stats
    from statsmodels.graphics.tsaplots import plot_acf
    
    res = (Prices['Prediction'] - Prices['Real']).to_numpy()
    
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 2) )

    ax[0].hist( res, bins = 100 )    
    plot_acf( res, ax=ax[1] )
# Out:
# [INFO] Feature:  NO2
# --------------------------------------------------

# %% [markdown]
# ## Examples

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]
plt.figure( figsize = (20, 8) )
RandomInstances = [random.randint(1, testY.shape[0]) for i in range(0, 9)]
RandomInstances = [913, 205, 2254, 2007, 1829, 1144, 840, 713, 3457]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    #
    plt.plot(range(Lag, Lag + Horizon), testY[i], color='g', marker = 'o', linewidth = 2)
    plt.plot(range(Lag, Lag + Horizon), pred[i],  color='r', marker = 'o', linewidth = 2)

    plt.legend(['Instance', 'Future values', 'Prediction'], frameon = False, fontsize = 12)
    
    plt.ylim([0, 180])
plt.show()

# %%
RandomInstances
# Out:
# [748, 334, 759, 728, 430, 547, 147, 351, 502]

# %% [markdown]
# # Store predictions

# %%
Outputs = pd.DataFrame( [] )


Outputs[ targetSeries ] = testY.flatten()
Outputs['NBeats_diff'] = pred.flatten()

Outputs.to_csv('Predictions/NBeats_diff.csv')
